# %%
from unstructured.partition.pdf import partition_pdf
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_pinecone import PineconeVectorStore
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
from dotenv import load_dotenv
import os
import glob

load_dotenv()

file_path = "C:/Users/User/Downloads/tmj_rag_app/Ingestion/data/pdfs"
index_name = os.getenv("PINECONE_INDEX")

# %%
# Get all PDF files in the folder
pdf_files = glob.glob(os.path.join(file_path, "*.pdf"))
print(f"Found {len(pdf_files)} PDF files to process")

# Partition all PDF files
all_elements = []
for pdf_file in pdf_files:
    base_file_name = os.path.splitext(os.path.basename(pdf_file))[0]
    print(f"Processing: {base_file_name}.pdf")
    
    elements = partition_pdf(
        filename=pdf_file,
        strategy="auto",
        infer_table_structure=True
    )
    
    # Store elements with their source file name
    for element in elements:
        element._source_file = base_file_name  # Store source file name
    
    all_elements.extend(elements)
    print(f"  Extracted {len(elements)} elements from {base_file_name}.pdf")

print(f"\nTotal elements extracted: {len(all_elements)}")
# Out:
# Found 11 PDF files to process
# Processing: tmjDoc1.pdf
# Warning: No languages specified, defaulting to English.
# The `max_size` parameter is deprecated and will be removed in v4.26. Please specify in `size['longest_edge'] instead`.
#   Extracted 251 elements from tmjDoc1.pdf
# Processing: tmjDoc10.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 59 elements from tmjDoc10.pdf
# Processing: tmjDoc11.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 19 elements from tmjDoc11.pdf
# Processing: tmjDoc2.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 164 elements from tmjDoc2.pdf
# Processing: tmjDoc3.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 33 elements from tmjDoc3.pdf
# Processing: tmjDoc4.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 137 elements from tmjDoc4.pdf
# Processing: tmjDoc5.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 143 elements from tmjDoc5.pdf
# Processing: tmjDoc6.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 24 elements from tmjDoc6.pdf
# Processing: tmjDoc7.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 63 elements from tmjDoc7.pdf
# Processing: tmjDoc8.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 72 elements from tmjDoc8.pdf
# Processing: tmjDoc9.pdf
# Warning: No languages specified, defaulting to English.
#   Extracted 37 elements from tmjDoc9.pdf
#
# Total elements extracted: 1002

# %%
# Display the elements partitioned from the PDF file
for i, element in enumerate(elements):
    print(f"\n--- Element {i} ---")
    print(f"Type: {element.category}")
    print(f"Text: {element.text}")
    print(f"Metadata: {element.metadata}")
# Out:
# --- Element 0 ---
# Type: Header
# Text: 12/5/25, 6:33 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB96995460>
#
# --- Element 1 ---
# Type: Header
# Text: Temporomandibular Disorders (TMD) Devices | FDA
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB96997980>
#
# --- Element 2 ---
# Type: Title
# Text: Temporomandibular Disorders (TMD) Devices
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB96994860>
#
# --- Element 3 ---
# Type: NarrativeText
# Text: Temporomandibular disorders (TMD) refer to an orofacial (face, head, or neck) pain condition in which pain and discomfort affect the temporomandibular joint (TMJ), the muscles, or the contiguous tissue components.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB562B96D0>
#
# --- Element 4 ---
# Type: Title
# Text: Updates on TMD Devices
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB959EDA90>
#
# --- Element 5 ---
# Type: ListItem
# Text: ¢ Postmarket surveillance study information, including study results (/medical- devices/temporomandibular-disorders-tmd-devices/fdas-role-approving-tmj-implants- and-monitoring-their-safety#surveillance)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB959ED580>
#
# --- Element 6 ---
# Type: ListItem
# Text: e FDA-approved TMJ implants (/medical-devices/temporomandibular-disorders-tmd- devices/fdas-role-approving-tmj-implants-and-monitoring-their-safety#fdaapproved),
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8761E870>
#
# --- Element 7 ---
# Type: NarrativeText
# Text: The TMJ is the part of the lower jaw, in front of the ear where the lower jaw connects to the to the skull. There is a TMJ on each side of the jaw. The TMJ is composed of three parts.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA6510>
#
# --- Element 8 ---
# Type: ListItem
# Text: e Mandibular condyle - the part of the joint located in the lower jaw.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA5970>
#
# --- Element 9 ---
# Type: ListItem
# Text: * Glenoid fossa - the part of the joint located at the base of the skull.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA5040>
#
# --- Element 10 ---
# Type: ListItem
# Text: e Meniscus - a small disc-shaped piece of cartilage, which serves as a cushion between the mandibular condyle and glenoid fossa.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA79E0>
#
# --- Element 11 ---
# Type: NarrativeText
# Text: For some patients, the pain in the TMJ is severe and unrelenting. Symptoms can include clicking or popping of the TM4J, pain in or around the TMJ and muscles, locking or limited opening of the mouth, headaches, pain behind the eyes, dizziness, earaches or ringing in
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA4680>
#
# --- Element 12 ---
# Type: Image
# Text: . : me - a é a & we y Fe, / Mandible ' CLOSED
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA46B0>
#
# --- Element 13 ---
# Type: Title
# Text: Credit:
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA5760>
#
# --- Element 14 ---
# Type: NarrativeText
# Text: https://www.fda.gov/medical-devices/dental-devices/temporomandibular-disorders-tmd-devices
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA4740>
#
# --- Element 15 ---
# Type: Header
# Text: yoeqpess
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8675C950>
#
# --- Element 16 ---
# Type: Header
# Text: 1/2
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA4DA0>
#
# --- Element 17 ---
# Type: Header
# Text: 12/5/25, 6:33 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8676CE90>
#
# --- Element 18 ---
# Type: Header
# Text: Temporomandibular Disorders (TMD) Devices | FDA
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB87507B00>
#
# --- Element 19 ---
# Type: UncategorizedText
# Text: the ears, clenching or grinding of the NIH/NIDGR (https:/www.nidcr.nih.gov/health-info/tmj/more-info)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACF8F0>
#
# --- Element 20 ---
# Type: NarrativeText
# Text: teeth, neck, shoulder or back pain, and
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB96997A70>
#
# --- Element 21 ---
# Type: NarrativeText
# Text: numbness or tingling of the fingers.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA5070>
#
# --- Element 22 ---
# Type: Title
# Text: Treatment Options
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA6540>
#
# --- Element 23 ---
# Type: NarrativeText
# Text: TMD is a complex medical condition which can be difficult to treat.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA5BE0>
#
# --- Element 24 ---
# Type: NarrativeText
# Text: Non-surgical treatment options include:
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA78C0>
#
# --- Element 25 ---
# Type: ListItem
# Text: ¢ Behavioral changes (for example, avoiding gum chewing)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB8EEA70B0>
#
# --- Element 26 ---
# Type: ListItem
# Text: e Short term use of pain medication
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACD2B0>
#
# --- Element 27 ---
# Type: ListItem
# Text: e Devices that may help relieve pain, such as ice packs
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACD5B0>
#
# --- Element 28 ---
# Type: ListItem
# Text: e Bite guards (also known as occlusal splints or nightguards)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACF680>
#
# --- Element 29 ---
# Type: ListItem
# Text: e Laser devices used to relieve muscle-related jaw pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACE0C0>
#
# --- Element 30 ---
# Type: NarrativeText
# Text: Surgical treatment options, which are more invasive, include:
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACD370>
#
# --- Element 31 ---
# Type: Title
# Text: e TMJ Implants
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACCC20>
#
# --- Element 32 ---
# Type: Title
# Text: IMJ implants (/medical-devices/temporomandibular-disorders-tmd-
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACEED0>
#
# --- Element 33 ---
# Type: NarrativeText
# Text: devices/temporomandibular-joint-tmj-implants) are intended to be implanted in the jaw to replace all or part of the temporomandibular joint. The purpose of these types of implants is to restore TMJ function, including opening and closing the mouth and chewing.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACFDA0>
#
# --- Element 34 ---
# Type: Image
# Text: Was this page helpful? * (required) Yes No Submit = An official form of the United States government. Provided by Touchpoints
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACCAD0>
#
# --- Element 35 ---
# Type: UncategorizedText
# Text: https://www.fda.gov/medical-devices/dental-devices/temporomandibular-disorders-tmd-devices
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACC4A0>
#
# --- Element 36 ---
# Type: Header
# Text: 2/2
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000001BB95ACE120>

# %%
# Convert to LangChain Documents from all PDFs
docs = []
MIN_CHAR_LENGTH = 50

for el in all_elements:
    #Skip headers, dont contain useful info
    if el.category == "Header":
        continue
    
    text = getattr(el, "text", None)
    if not text:
        continue

    if (len(text.strip()) < MIN_CHAR_LENGTH):
        continue

    # Get source file name from the element
    source_file = getattr(el, "_source_file", "unknown")
    
    meta = el.to_dict().get("metadata", {}) or {}
    docs.append(
        Document(
            page_content=text,
            metadata={
                "source": source_file,
                "page_number": meta.get("page_number"),
                "type": el.category if hasattr(el, "category") else meta.get("type"),
            },
        )
    )

print(f"Total documents created: {len(docs)}")
print(f"Documents from {len(set(doc.metadata.get('source') for doc in docs))} different PDFs")

#Print first few documents as sample
for i, doc in enumerate(docs[:5], 1):  # Show first 5 as sample
    meta = doc.metadata
    print(f"--- Document {i} ---")
    print(f"Source: {meta.get('source')} | Page: {meta.get('page_number')} | Type: {meta.get('type')}")
    print(f"Content length: {len(doc.page_content)} characters")
    print(f"Content:\n{doc.page_content}")
    print()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, 
    chunk_overlap=200,
    add_start_index=True
)
chunked_docs = splitter.split_documents(docs)
print(f"Total chunks created: {len(chunked_docs)}")
# Out:
# Total documents created: 426
# Documents from 11 different PDFs
# --- Document 1 ---
# Source: tmjDoc1 | Page: 1 | Type: NarrativeText
# Content length: 73 characters
# Content:
# = An official website of the United States government Here’s how you know
#
# --- Document 2 ---
# Source: tmjDoc1 | Page: 1 | Type: NarrativeText
# Content length: 54 characters
# Content:
# National Institute of Dental and Craniofacial Research
#
# --- Document 3 ---
# Source: tmjDoc1 | Page: 1 | Type: UncategorizedText
# Content length: 60 characters
# Content:
# </espanol/temas-de-salud/los-trastornos-temporomandibulares>
#
# --- Document 4 ---
# Source: tmjDoc1 | Page: 2 | Type: NarrativeText
# Content length: 221 characters
# Content:
# Temporomandibular disorders (TMDs) area group of more than 30 conditions that cause pain and dysfunction in the jaw joint and muscles that control jaw movement. “TMDs” refers to the disorders, and “TMJ” refers only to the
#
# --- Document 5 ---
# Source: tmjDoc1 | Page: 2 | Type: UncategorizedText
# Content length: 81 characters
# Content:
# Healthy temporomandibular joint during mouth opening & closing. temporomandibular
#
# Total chunks created: 426

# %%
#Print the chunked documents
for i, doc in enumerate(chunked_docs, 1):
    meta = doc.metadata
    print(f"--- Chunk {i} ---")
    print(f"source={meta.get('source')} page={meta.get('page_number')} type={meta.get('type')} section={meta.get('section')}")
    print(doc.page_content)
    print()
# Out:
# --- Chunk 1 ---
# source=tmjDoc1 page=1 type=NarrativeText section=None
# = An official website of the United States government Here’s how you know
#
# --- Chunk 2 ---
# source=tmjDoc1 page=1 type=NarrativeText section=None
# National Institute of Dental and Craniofacial Research
#
# --- Chunk 3 ---
# source=tmjDoc1 page=1 type=UncategorizedText section=None
# </espanol/temas-de-salud/los-trastornos-temporomandibulares>
#
# --- Chunk 4 ---
# source=tmjDoc1 page=2 type=NarrativeText section=None
# Temporomandibular disorders (TMDs) area group of more than 30 conditions that cause pain and dysfunction in the jaw joint and muscles that control jaw movement. “TMDs” refers to the disorders, and “TMJ” refers only to the
#
# --- Chunk 5 ---
# source=tmjDoc1 page=2 type=UncategorizedText section=None
# Healthy temporomandibular joint during mouth opening & closing. temporomandibular
#
# --- Chunk 6 ---
# source=tmjDoc1 page=2 type=NarrativeText section=None
# itself. People have two TMJs; one on each side of the jaw. You can feel them by placing your fingers in front of your ears and opening your mouth.
#
# --- Chunk 7 ---
# source=tmjDoc1 page=2 type=NarrativeText section=None
# 1. Disorders of the joints, including disc disorders.
#
# --- Chunk 8 ---
# source=tmjDoc1 page=2 type=NarrativeText section=None
# 2. Disorders of the muscles used for chewing (masticatory muscles).
#
# --- Chunk 9 ---
# source=tmjDoc1 page=2 type=NarrativeText section=None
# There are several disorders within each class. See diagram below for some examples.
#
# --- Chunk 10 ---
# source=tmjDoc1 page=3 type=Title section=None
# Classification of Temporomandibular Disorders (TMDs) with Examples
#
# --- Chunk 11 ---
# source=tmjDoc1 page=3 type=NarrativeText section=None
# Text Alternative </health-info/tmd/classification-temporomandibular-disorders-tmds-examples-text-
#
# --- Chunk 12 ---
# source=tmjDoc1 page=3 type=Image section=None
# Temporomandibular Disorders * Disorders of the muscles Disorders of the joints used for chewing Headaches associated (masticatory muscles) wakine THD Examples: Examples: A) Pain located in one area that Any type of headache along gets worse with things such as with a painful TMD A) Joint pain (arthralgia) applying pressure (myalgia) B) Pain that spreads beyond the point where it starts or pain felt in an area of the body far away from where it started (myofascial C) Bone destruction pain without/with referral) (degenerative joint disease) B) Disc disorders (disc is not in its normal position)
#
# --- Chunk 13 ---
# source=tmjDoc1 page=3 type=NarrativeText section=None
# *A person may have one or more of these conditions at the same time.
#
# --- Chunk 14 ---
# source=tmjDoc1 page=3 type=NarrativeText section=None
# Many TMDs last only a short time and go away on their own. However, in some cases they can become chronic, or long lasting. In addition, TMDs can occur alone or at the same time as other medical conditions such as headaches, back pain, sleep problems, fibromyalgia, and irritable bowel syndrome.
#
# --- Chunk 15 ---
# source=tmjDoc1 page=3 type=NarrativeText section=None
# A recent study found that about 11-12 million adults in the United States had pain in the region of the temporomandibular joint.
#
# --- Chunk 16 ---
# source=tmjDoc1 page=3 type=NarrativeText section=None
# Temporomandibular disorders are twice as common in women than in men, especially in women between 35 and 44 years old.
#
# --- Chunk 17 ---
# source=tmjDoc1 page=4 type=NarrativeText section=None
# Injury to the jaw or temporomandibular joint can lead to some TMDs, but in most cases, the exact cause is not clear. For many people, symptoms seem to start without obvious reason. Recent research suggests a combination of genes, psychological and life stressors, and how someone perceives pain, may play a part in why a TMD starts and whether it will be long lasting.
#
# --- Chunk 18 ---
# source=tmjDoc1 page=4 type=NarrativeText section=None
# Because TMDs are more common in women than in men, researchers are exploring whether the differences in TMJ structure and mechanics between females and males may play a role.
#
# --- Chunk 19 ---
# source=tmjDoc1 page=4 type=NarrativeText section=None
# Research does not support the belief that a bad bite or orthodontic braces cause TMDs.
#
# --- Chunk 20 ---
# source=tmjDoc1 page=4 type=NarrativeText section=None
# It is important to know that sounds (such as clicking or popping) without pain in the TMJs are common, are considered normal, and don’t need treatment.
#
# --- Chunk 21 ---
# source=tmjDoc1 page=4 type=ListItem section=None
# e Pain in the chewing muscles and/or jaw joint (most common symptom),
#
# --- Chunk 22 ---
# source=tmjDoc1 page=4 type=ListItem section=None
# e Painful clicking, popping, or grating in the jaw joint when opening or closing the mouth.
#
# --- Chunk 23 ---
# source=tmjDoc1 page=4 type=ListItem section=None
# e Ringing in the ears, hearing loss, or dizziness.
#
# --- Chunk 24 ---
# source=tmjDoc1 page=4 type=ListItem section=None
# ¢ Achange in the way the upper and lower teeth fit together.
#
# --- Chunk 25 ---
# source=tmjDoc1 page=5 type=NarrativeText section=None
# There is no widely accepted, standard test available to diagnose TMDs. Because the exact causes and symptoms are not clear, identifying these disorders can be difficult.
#
# --- Chunk 26 ---
# source=tmjDoc1 page=5 type=NarrativeText section=None
# Your doctor or dentist will note your symptoms and take a detailed medical history. He or she will ask questions about your pain, including its location, when it occurs, what makes it better or worse, and if it stays in one area or spreads to other parts of your body. The doctor or dentist will also ask if you have other pain conditions such as headache or back pain.
#
# --- Chunk 27 ---
# source=tmjDoc1 page=5 type=NarrativeText section=None
# He or she also will examine your head, neck, face, and jaw for tenderness; jaw clicking or popping; or difficulty with movement. The doctor or dentist might also suggest imaging studies such as an x-ray, magnetic resonance imaging (MRI), or computed tomography (CT).
#
# --- Chunk 28 ---
# source=tmjDoc1 page=5 type=NarrativeText section=None
# Pain in the mouth, jaw, or face may or may not be related to TMDs. Your doctor or dentist may have to rule out other conditions before diagnosing a TMD.
#
# --- Chunk 29 ---
# source=tmjDoc1 page=5 type=NarrativeText section=None
# Before receiving treatment for TMDs, you should know:
#
# --- Chunk 30 ---
# source=tmjDoc1 page=5 type=ListItem section=None
# ¢ Sounds without pain in the temporomandibular joints are normal, happen frequently, and do not need treatment.
#
# --- Chunk 31 ---
# source=tmjDoc1 page=5 type=ListItem section=None
# e Signs and symptoms of TMD go away in many people without treatment.
#
# --- Chunk 32 ---
# source=tmjDoc1 page=5 type=ListItem section=None
# e Because evidence is lacking for the majority of TMD treatments, experts strongly recommend staying away from treatments that cause permanent changes to the jaw joints, teeth, or bite; or that involve surgery.
#
# --- Chunk 33 ---
# source=tmjDoc1 page=6 type=NarrativeText section=None
# Because many jaw joint and muscle problems are temporary and do not get worse, simple treatment may be all that is necessary.
#
# --- Chunk 34 ---
# source=tmjDoc1 page=6 type=NarrativeText section=None
# When you first feel discomfort in your jaw joints or muscles, your doctor or dentist may have you:
#
# --- Chunk 35 ---
# source=tmjDoc1 page=6 type=ListItem section=None
# ¢ Apply heat or cold to the face in combination with exercises to gently stretch and strengthen the jaw muscles.
#
# --- Chunk 36 ---
# source=tmjDoc1 page=6 type=ListItem section=None
# ¢ Take over-the-counter medications, for example nonsteroidal anti- inflammatory drugs (NSAIDs), like ibuprofen.
#
# --- Chunk 37 ---
# source=tmjDoc1 page=6 type=ListItem section=None
# e Reduce habits such as jaw clenching, gum chewing, or nail biting.
#
# --- Chunk 38 ---
# source=tmjDoc1 page=6 type=NarrativeText section=None
# If these steps do not help, or if in the process of trying them your doctor/dentist diagnoses a specific type of TMD, one or more of the following treatments may be recommended.
#
# --- Chunk 39 ---
# source=tmjDoc1 page=6 type=NarrativeText section=None
# The goal of physical therapy is to maintain, improve, or bring back movement and physical function. There are several types of physical therapy. One type is manual therapy, in which a therapist uses his/her hands to stretch the soft tissues and muscles around the joint. Manual therapy has been shown to help improve function and relieve pain.
#
# --- Chunk 40 ---
# source=tmjDoc1 page=6 type=NarrativeText section=None
# Self-management refers to activities you can do yourself and include:
#
# --- Chunk 41 ---
# source=tmjDoc1 page=6 type=ListItem section=None
# e Learn all you can about your specific type(s) of TMD.
#
# --- Chunk 42 ---
# source=tmjDoc1 page=6 type=ListItem section=None
# ¢ Set specific goals related to managing your condition.
#
# --- Chunk 43 ---
# source=tmjDoc1 page=7 type=ListItem section=None
# ¢ Stay involved in activities that are meaningful to you.
#
# --- Chunk 44 ---
# source=tmjDoc1 page=7 type=NarrativeText section=None
# Certain behavioral health approaches, usually offered by a psychologist, have been shown to help manage TMDs. These include cognitive behavioral therapy and biofeedback.
#
# --- Chunk 45 ---
# source=tmjDoc1 page=7 type=NarrativeText section=None
# Cognitive behavioral therapy seeks to identify negative thoughts or thought patterns and change them, as well as provide coping skills.
#
# --- Chunk 46 ---
# source=tmjDoc1 page=7 type=NarrativeText section=None
# Biofeedback involves using sensors that monitor breathing, heart rate, muscle contraction, and temperature. For example, a sensor on your jaw can detect when you tighten your jaw muscles. With the help of a therapist, you can learn to notice the unwanted behavior and relax.
#
# --- Chunk 47 ---
# source=tmjDoc1 page=7 type=NarrativeText section=None
# Your doctor or dentist may recommend medication(s) to treat your symptoms.
#
# --- Chunk 48 ---
# source=tmjDoc1 page=7 type=ListItem section=None
# ¢ Nonsteroidal anti-inflammatory drugs (NSAIDs), used to treat pain.
#
# --- Chunk 49 ---
# source=tmjDoc1 page=7 type=NarrativeText section=None
# Some of these medications can lead to addiction or have other serious side effects. If you are prescribed any of these medications, make sure your doctor or dentist explains how to take them and for how long.
#
# --- Chunk 50 ---
# source=tmjDoc1 page=8 type=NarrativeText section=None
# Intraoral appliances are devices that fit over the teeth. They do not change teeth or bite. They are also known as nightguards, splints, stabilization appliances, occlusal splints, interocclusal splints, or bruxism splints.
#
# --- Chunk 51 ---
# source=tmjDoc1 page=8 type=NarrativeText section=None
# There is not a lot of evidence they improve TMD pain. If a dentist or doctor suggests you use one:
#
# --- Chunk 52 ---
# source=tmjDoc1 page=8 type=ListItem section=None
# e Make sure it is not designed to permanently change your bite.
#
# --- Chunk 53 ---
# source=tmjDoc1 page=8 type=ListItem section=None
# ¢ Stop using it and consult your dentist/doctor if it causes pain.
#
# --- Chunk 54 ---
# source=tmjDoc1 page=8 type=NarrativeText section=None
# Acomplementary treatment is a non-mainstream practice used together with conventional medicine. Acupuncture and transcutaneous electrical nerve stimulation (TENS) are two complementary treatments that have been studied for TMDs.
#
# --- Chunk 55 ---
# source=tmjDoc1 page=8 type=NarrativeText section=None
# Acupuncture is a technique in which practitioners stimulate specific points on the body—most often by inserting thin needles through the skin. There is limited evidence that it helps TMDs.
#
# --- Chunk 56 ---
# source=tmjDoc1 page=8 type=NarrativeText section=None
# TENS is a battery-powered device that uses electrodes placed on the skin. The device creates electrical impulses that may change how pain is perceived. Although some studies have shown that TENS may help relieve pain in TMDs and improve the ability to open the mouth, the studies were small with short- duration TENS treatments.
#
# --- Chunk 57 ---
# source=tmjDoc1 page=8 type=NarrativeText section=None
# The treatments discussed in this section are more complex, involve going into the chewing muscles or the temporomandibular joints (with a needle or other instrument), or changing your bite and teeth. More importantly, some of them
#
# --- Chunk 58 ---
# source=tmjDoc1 page=9 type=Title section=None
# like occlusal treatments (see below)— don’t work and may make the problem worse. Before having any of these procedures:
#
# --- Chunk 59 ---
# source=tmjDoc1 page=9 type=ListItem section=None
# e Ask about simpler treatments and try those first.
#
# --- Chunk 60 ---
# source=tmjDoc1 page=9 type=ListItem section=None
# e Ask the doctor or dentist to explain the procedure—in detail—in a way you can understand.
#
# --- Chunk 61 ---
# source=tmjDoc1 page=9 type=ListItem section=None
# Ask how the procedure will help improve your specific TMD.
#
# --- Chunk 62 ---
# source=tmjDoc1 page=9 type=ListItem section=None
# ¢ Get second opinions from qualified medical or dental specialists.
#
# --- Chunk 63 ---
# source=tmjDoc1 page=9 type=NarrativeText section=None
# Occlusion refers to how teeth fit together. For years it was thought that misaligned teeth (malocclusion) were a cause of TMDs; however, there is no evidence to support this belief. Occlusal treatments modify the teeth and bite. Examples include:
#
# --- Chunk 64 ---
# source=tmjDoc1 page=9 type=ListItem section=None
# e Using orthodontic treatment(s) to change the position of some or all teeth.
#
# --- Chunk 65 ---
# source=tmjDoc1 page=9 type=Title section=None
# There is no evidence these occlusal treatments work, and they could make the problem worse.
#
# --- Chunk 66 ---
# source=tmjDoc1 page=9 type=NarrativeText section=None
# Botulinum toxin Type A works by relaxing muscles. It is FDA-approved for some medical conditions (like migraines) but not for TMDs. Studies have looked at injecting botulinum toxin Type A into the chewing muscles to reduce muscle spasm and pain. However, the information from these studies is limited and it is not clear whether this medication works to relieve TMD symptoms.
#
# --- Chunk 67 ---
# source=tmjDoc1 page=10 type=NarrativeText section=None
# Prolotherapy involves injecting a solution into the TMJ area that causes irritation, with the goal of triggering the body to respond by repairing the joint. Prolotherapy has shown promise specifically for TMDs in which the joint is out of its normal position (dislocation) or when the joint goes beyond its normal range of movement (hypermobility). However, there have been only a few small studies on this treatment for TMDs.
#
# --- Chunk 68 ---
# source=tmjDoc1 page=10 type=NarrativeText section=None
# In this procedure a needle is used to push liquid into the TMJ. The pressure caused by the liquid removes scar-like tissue (adhesions). In addition, when the liquid is flushed out of the joint, it removes substances that cause inflammation. Arthrocentesis has been shown to help with pain relief and improve mouth opening in people whose temporomandibular disc is out of place; however, these effects do not last long.
#
# --- Chunk 69 ---
# source=tmjDoc1 page=10 type=NarrativeText section=None
# During arthroscopy the doctor inserts an instrument with a tiny video camera into the jaw joint. The doctor can see the joint, which can help in diagnosis. He or she can also remove adhesions or reposition the joint’s disc. This procedure works moderately well in helping improve pain and function.
#
# --- Chunk 70 ---
# source=tmjDoc1 page=10 type=NarrativeText section=None
# Open surgery gives access to the temporomandibular joint through a cut (incision) next to the ear. It’s important to know that surgery makes permanent changes to your joint. There are no long-term research studies on the safety of open surgery for TMDs or on how well it works to relieve symptoms.
#
# --- Chunk 71 ---
# source=tmjDoc1 page=10 type=ListItem section=None
# ¢ There is destruction of the joint that cannot be fixed with other procedures.
#
# --- Chunk 72 ---
# source=tmjDoc1 page=11 type=ListItem section=None
# e There are severe symptoms (pain and/or difficulty opening the mouth), despite trying other treatments.
#
# --- Chunk 73 ---
# source=tmjDoc1 page=11 type=NarrativeText section=None
# If your healthcare provider suggests surgery, be sure to ask:
#
# --- Chunk 74 ---
# source=tmjDoc1 page=11 type=NarrativeText section=None
# Implants are artificial devices that are used to replace part of the jaw joint or the entire joint. There are currently three TMJ implants approved by the FDA.
#
# --- Chunk 75 ---
# source=tmjDoc1 page=11 type=ListItem section=None
# e There is a condition you’re born with (congenital condition) that needs to be repaired.
#
# --- Chunk 76 ---
# source=tmjDoc1 page=11 type=ListItem section=None
# ¢ The joint is frozen (ankylosis), commonly caused by injury or infection.
#
# --- Chunk 77 ---
# source=tmjDoc1 page=11 type=ListItem section=None
# All simpler treatments have been tried and have failed.
#
# --- Chunk 78 ---
# source=tmjDoc1 page=11 type=NarrativeText section=None
# Some studies suggest that, when used in very specific cases, TMJ implants can improve function and quality of life. As with any surgery, proceed with caution.
#
# --- Chunk 79 ---
# source=tmjDoc1 page=11 type=NarrativeText section=None
# Implants used many years ago (and since taken off the market), did not help patients and left them with severe complications, including permanent damage to the jaw joint(s). Because of this, researchers have called for long-term studies to look at the safety and efficacy of the newer TMJ implants.
#
# --- Chunk 80 ---
# source=tmjDoc1 page=12 type=NarrativeText section=None
# Remember: Before any surgery, including implant surgery, it is extremely important to get opinions from more than one doctor and to completely understand the risks. If possible, seek an opinion from a surgeon who specializes in treating TMDs.
#
# --- Chunk 81 ---
# source=tmjDoc1 page=12 type=Title section=None
# Summary of Treatments for Temporomandibular Disorders (TMDs)
#
# --- Chunk 82 ---
# source=tmjDoc1 page=12 type=NarrativeText section=None
# Text Alternative </health-info/tmd/summary-treatment-temporomandibular-disorders-tmds-text-
#
# --- Chunk 83 ---
# source=tmjDoc1 page=12 type=Table section=None
# Simplest treatments; try Could be prescribed by Proceed with caution Only consider these these treatments first. doctor or dentist as a if these treatments are if doctor or dentist + Eating soft foods + Applying heat/cold to face + Jaw stretching & strengthening exercises * Short-term over-the-counter NSAIDs + Self-management second step if simpler treatments do not help. + Behavioral health approaches (usually offered by a psychologist) + Physical therapy, including manual therapy (needs referral by doctor or dentist) + Prescription medications + Intraoral appliances * Complementary treatments recommended. They involve going into the jaw joint using needles or other instruments. + Prolotherapy + Arthrocentesis + Arthroscopy recommends as a last_ resort; ask for second opinion. Involves direct access and permanent changes to the jaw joint. + Surgery, including TMJ implants
#
# --- Chunk 84 ---
# source=tmjDoc1 page=12 type=NarrativeText section=None
# Botulinum toxin Type A injections and occlusal treatments are not listed in this table because: + Researchers do not have conclusive evidence that botulinum toxin Type A injections into the chewing muscles help with TMDs. * Occlusal treatments including placing crowns, grinding down teeth, and orthodontic treatments do not help TMDs and can make the problem worse.
#
# --- Chunk 85 ---
# source=tmjDoc1 page=12 type=Title section=None
# If you think you have a TMD or are diagnosed with one:
#
# --- Chunk 86 ---
# source=tmjDoc1 page=13 type=ListItem section=None
# ¢ Start with simple treatments first; remember that TMD symptoms often go away on their own, without treatment.
#
# --- Chunk 87 ---
# source=tmjDoc1 page=13 type=ListItem section=None
# e Avoid (when possible) treatments that involve going into or permanently changing the jaw joints, especially surgery or TMJ implants.
#
# --- Chunk 88 ---
# source=tmjDoc1 page=13 type=ListItem section=None
# e Understand all the risks when considering surgery or other medical or dental procedures that result in permanent change and seek an opinion from an orofacial pain clinic at a medical or dental school, if possible.
#
# --- Chunk 89 ---
# source=tmjDoc1 page=13 type=Title section=None
# Temporomandibular Disorders and Jaw Pain </research/data-
#
# --- Chunk 90 ---
# source=tmjDoc1 page=13 type=NarrativeText section=None
# <https://www.nlm.nih.gov/medlineplus/temporomandibularjointdysfunction.html>
#
# --- Chunk 91 ---
# source=tmjDoc1 page=13 type=NarrativeText section=None
# The NIH National Library of Medicine's collection of links to government, professional, and non-profit/voluntary organizations with information on temporomandibular disorders.
#
# --- Chunk 92 ---
# source=tmjDoc1 page=13 type=NarrativeText section=None
# The TMJ Association is a non-profit, patient advocacy organization whose mission is to improve the quality of health care and the lives of everyone affected by temporomandibular disorders.
#
# --- Chunk 93 ---
# source=tmjDoc1 page=13 type=ListItem section=None
# American Chronic Pain Association <https://www.acpanow.com/> The ACPA offers peer support and education in pain management skills to people with pain, their family and friends, and health care professionals.
#
# --- Chunk 94 ---
# source=tmjDoc1 page=14 type=Title section=None
# TMD (Temporomandibular Disorders) Research from NIDCR
#
# --- Chunk 95 ---
# source=tmjDoc1 page=14 type=Title section=None
# e Why Aging Matters for Bone Healing: New Clues from the Rib </news-
#
# --- Chunk 96 ---
# source=tmjDoc1 page=14 type=NarrativeText section=None
# events/nidcr-news/why-aging-matters-bone-healing-new-clues-rib>
#
# --- Chunk 97 ---
# source=tmjDoc1 page=14 type=ListItem section=None
# ¢ Our Jaw Shape May Foretell Risk of Temporomandibular Disorders </news- events/nidcr-news/2024/our-jaw-shape-may-foretell-risk-temporomandibular-disorders>
#
# --- Chunk 98 ---
# source=tmjDoc1 page=14 type=ListItem section=None
# ¢ NIDCRis PRIMED to move AHEAD with IMPACT: Institute Awards $14 Million to Tackle Unsolved Clinical Challenges </news-events/nidcr-news/2023/nidcr-primed-
#
# --- Chunk 99 ---
# source=tmjDoc1 page=14 type=UncategorizedText section=None
# move-ahead-impact-institute-awards-14-million-tackle-unsolved-clinical>
#
# --- Chunk 100 ---
# source=tmjDoc1 page=14 type=ListItem section=None
# e Looking Forward to Greater IMPACT on Temporomandibular Disorders </news-events/nidcr-news/2023/looking-forward-greater-impact-temporomandibular-disorders>
#
# --- Chunk 101 ---
# source=tmjDoc1 page=14 type=Title section=None
# ¢ Inflammation May Curb, Not Cause, Chronic Pain </news-events/nidcr-
#
# --- Chunk 102 ---
# source=tmjDoc1 page=14 type=UncategorizedText section=None
# news/2022/inflammation-may-curb-not-cause-chronic-pain>
#
# --- Chunk 103 ---
# source=tmjDoc1 page=14 type=NarrativeText section=None
# Web Policies </about-us/web- Privacy </about-us/privacy-policy>
#
# --- Chunk 104 ---
# source=tmjDoc1 page=14 type=NarrativeText section=None
# Contact Us </about-us/contact- Freedom of Information No Fear Act
#
# --- Chunk 105 ---
# source=tmjDoc10 page=1 type=Title section=None
# FDA's Role in Approving TMJ Implants and Monitoring Their Safety
#
# --- Chunk 106 ---
# source=tmjDoc10 page=1 type=NarrativeText section=None
# Among its many responsibilities, the FDA is charged with helping to ensure the safety FDA's Role in Approving TMJ Implants and Monitoring Their Safety and effectiveness of medical products, including medical devices used to treat Temporomandibular Disorder (TMD), such as Joint
#
# --- Chunk 107 ---
# source=tmjDoc10 page=1 type=NarrativeText section=None
# The FDA reviews TMJ implants before they are marketed and continues to monitor their performance and to take action when problems are discovered. The FDA monitors reports of adverse events and other problems with medical devices, and alerts health professionals and the public when needed to ensure proper use of devices and the health and safety of patients.
#
# --- Chunk 108 ---
# source=tmjDoc10 page=1 type=ListItem section=None
# Postmarket Surveillance Studies (522 Studies) of TMJ Implants
#
# --- Chunk 109 ---
# source=tmjDoc10 page=1 type=NarrativeText section=None
# The FDA requires premarket approval (PMA) applications for all TMJ implants. A PMA is the most stringent type of device marketing application required by the FDA. The FDA approves a PMA based on a determination that the PMA contains sufficient valid scientific evidence to provide reasonable assurance of the safety and effectiveness of that the device for its intended use. For information about approved TMJ implants, you may search our public database for
#
# --- Chunk 110 ---
# source=tmjDoc10 page=1 type=ListItem section=None
# « Joint, temporomandibular, implant (Product Code LZD) (https:/Awww.accessdata.fda.gov/scripts/cdrh/cfdocs/cfPMA/pma.cfm? start_search=1&applicant=&tradename=&productcode=|zd&pmanumber=&supplementnumber=&advisorycommittee=&docketnumber=&supplemen
#
# --- Chunk 111 ---
# source=tmjDoc10 page=1 type=ListItem section=None
# + Glenoid fossa prosthesis (Product Code MPI) (https:/Awww.accessdata.fda.govw/scripts/cdrh/cfdocs/cfPMA/pma.cfm?
#
# --- Chunk 112 ---
# source=tmjDoc10 page=1 type=ListItem section=None
# start_search=1 &applicant=&tradename=&productcode=MP|&pmanumber=&supplementnumber=&advisorycommittee=&docketnumber=&suppleme
#
# --- Chunk 113 ---
# source=tmjDoc10 page=1 type=NarrativeText section=None
# The FDA's Device Tracking Regulation (/medical-devices/postmarket-requirements-devices/medical-device-tracking) requires manufacturers, distributors, and hospitals to establish systems to track certain medical devices whose failure may pose a serious health risk to the public. These tracking systems help manufacturers contact patients with information regarding significant device problems, changes to the device label, or if an implant needs to be recalled. Since 1993, the FDA has included TMJ implants on the list of tracked devices because failure of these implanted devices would be reasonably likely to have serious, adverse health consequences. The FDA continues to list TMJ implants as tracked devices because the potential serious, adverse health consequences are still applicable to TMJ implants on the market today.
#
# --- Chunk 114 ---
# source=tmjDoc10 page=1 type=NarrativeText section=None
# The manufacturing companies and the FDA also have other approaches to notify the public about a recall (removal or correction) (/medical- devices/postmarket-requirements-devices/recalls-corrections-and-removals-devices). Some examples include changing the device label, issuing press releases, posting on social media sites, sending emails, and posting on FDA.gov and company websites. For more details, review the FDA guidance, Public Warning_and Notification of Recalls Under 21 CFR Part 7 (/regulatory-information/search-fda-guidance-documents/public-warning- notification-recalls-under-21-cfr-part-7-subpart-c).
#
# --- Chunk 115 ---
# source=tmjDoc10 page=1 type=NarrativeText section=None
# As a condition of approval for each approved TMJ implant device, the FDA required that the manufacturer conduct a post-approval study (/medical- devices/postmarket-requirements-devices/post-approval-studies-program), to help assure the continued safety and effectiveness of approved devices. A post-approval study is intended to gather specific information to address questions about the postmarket performance of or experience with an approved medical device. The Post-Approval Studies Database provides general information regarding each study:
#
# --- Chunk 116 ---
# source=tmjDoc10 page=1 type=ListItem section=None
# « Nexus CMF TMJ Fossa-Eminence/Condylar Prostheses (https://www.accessdata .fda.gov/scripts/cdrh/cfdocs/cfpma/pma_pas.cfm? t_id=89805&c_id=175)
#
# --- Chunk 117 ---
# source=tmjDoc10 page=1 type=UncategorizedText section=None
# https://www.fda.gov/medical-devices/temporomandibular-disorders-tmd-devices/fdas-role-approving-tmj-implants-and-monitoring-their-safety#surveilla... 1/3
#
# --- Chunk 118 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# « Nexus CMF TMJ Fossa-Eminence Prosthesis (https://www.accessdata. fda.gov/scripts/cdrh/cfdocs/cfpma/pma_pas.cfm? t_id=90175&c_id=180)
#
# --- Chunk 119 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# « TMJ Concepts Patient-Fitted TMJ Reconstruction Prosthesis: Long Term
#
# --- Chunk 120 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# (https:/Avww.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpma/pma_pas.cfm?t_id=90012&c_id=179),
#
# --- Chunk 121 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# ¢ Biomet Microfixation Walter Lorenz Total TMJ Replacement System: Long term Follow up Study (https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpma/pma_pas.cfm?t_id=90097&c_id=31)
#
# --- Chunk 122 ---
# source=tmjDoc10 page=2 type=Title section=None
# Postmarket Surveillance Studies (522 Studies) of TMJ Implants
#
# --- Chunk 123 ---
# source=tmjDoc10 page=2 type=NarrativeText section=None
# The FDA also ordered all TMJ implant manufacturers to conduct postmarket surveillance studies (/medical-devices/postmarket-requirements- devices/522-postmarket-surveillance-studies-program), also known as 522 studies. The FDA ordered the 522 studies over concerns arising from medical device reports (MDRs) submitted to the FDA, including adverse events observed over the expected lifetime of implanted TMJ devices, and timing and reasons for implant revision or replacement. Additional information about these studies is available in our 522 postmarket surveillance studies database (https://www.accessdata .fda.gov/scripts/cdrh/cfdocs/cfpma/pss.cfm). Studies include:
#
# --- Chunk 124 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# ¢ Biomet Microfixation Total Temporomandibular Joint Replacement System (P020016)
#
# --- Chunk 125 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# o Time to Revision study (https://\www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfPMA/pss.cfm?t_id=41&c_id=394),
#
# --- Chunk 126 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# o Explant study (https:/Awww.accessdata fda.gov/scripts/cdrh/cfdocs/cfPMA/pss.cfim?t_id=41&c_id=400)
#
# --- Chunk 127 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# « TMJ Concepts Patient-fitted TMJ Reconstruction Prosthesis System (P980052)
#
# --- Chunk 128 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# © Time to Revision and Explant Analysis study (https://Awww.accessdata.fda.gov/scripts/cdrh/cfdocs/cfPMA/pss.cim?t_id=40&c_id=393)
#
# --- Chunk 129 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# Nexus CMF TMJ Fossa-Eminence/Condylar Prosthesis Systems (P000035 and P000023)
#
# --- Chunk 130 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# o Prospective study (https://www.accessdata fda.gov/scripts/cdrh/cfdocs/cfPMA/pss.cfm?t_id=39&c_id=3851)
#
# --- Chunk 131 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# o Explant Analysis study (https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfPMA/pss.cfm?t_id=39&c_id=3852)
#
# --- Chunk 132 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# ¢ 2018: Patient-Led RoundTable at the annual Medical Device Epidemiology Network Initiative (MDEpiNet) meeting (http://mdepinet.org/wp- content/uploads/TMJ-Patient-RoundTable-Briefing-Report_9_25_18.pdf) @ (http://www.fda.gov/about-fda/website-policies/website-disclaimer) (PDF)
#
# --- Chunk 133 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# « 2011: The FDA ordered all three manufacturers of the four FDA-approved TMJ implants to conduct postmarket surveillance studies to better understand the events associated with the need to remove (explant) TMJ implants and replace (revise) TMJ implants.
#
# --- Chunk 134 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# « 2007: Government Accountability Office (GAO) published Report on FDA's Approval of Four Temporomandibular Joint Implants
#
# --- Chunk 135 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# « 2005: The FDA approved the Biomet Microfixation, Inc., Total Temporomandibular Joint Replacement System device (P020016 (https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpma/pma.cfm?id=P020016)).
#
# --- Chunk 136 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# « 2001: The FDA approved the TMJ Implants, Inc., TMJ Fossa-Eminence Prosthesis (P000035 (https://Awww.accessdata.fda.gow/scripts/cdrh/cfdocs/cfpma/pma.cfm?id=P000035)).
#
# --- Chunk 137 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# ¢ 2001: The FDA approved the Nexus CMF LLC (formerly TMJ Implants, Inc.), TMJ Fossa-Eminence/Condylar Prosthesis System (P000023 (https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpma/pma.cfm?id=P000023)).
#
# --- Chunk 138 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# « 1999: The FDA approved the TMJ Concepts Patient-Fitted TMJ Reconstruction Prosthesis (P980052 (https://www.accessdata.fda.gov/scripts/cdrh/cfdocs/cfpma/pma.cfm?id=p980052))
#
# --- Chunk 139 ---
# source=tmjDoc10 page=2 type=ListItem section=None
# « 1998: The FDA published a final rule (https://www.govinfo.gov/content/pkg/F R-1998-12-30/pdf/98-34483.pdf) (PDF) establishing the effective date of the requirement for premarket approval
#
# --- Chunk 140 ---
# source=tmjDoc10 page=2 type=UncategorizedText section=None
# https://www.fda.gov/medical-devices/temporomandibular-disorders-tmd-devices/fdas-role-approving-tmj-implants-and-monitoring-their-safety#surveilla... 2/3
#
# --- Chunk 141 ---
# source=tmjDoc11 page=1 type=NarrativeText section=None
# Temporomandibular disorders, commonly called “TMD,” are a group of painful conditions that affect the jaw joint and the muscles that control jaw movement. “TMD” refers to the disorders, and “TMJ” refers to the temporomandibular joint itself. People have two TMJs; one on each side of the jaw. Injury to the jaw can sometimes lead to TMDs, but in most cases the cause is not clear. Recent research suggests a combination of genes, psychological and life stressors, and how someone perceives pain may play a part in why a TMD starts and whether it will be long-lasting.
#
# --- Chunk 142 ---
# source=tmjDoc11 page=1 type=NarrativeText section=None
# The good news is that for many people, pain in the TMJ does not signal a serious problem and signs and symptoms will go away without treatment. TMDs are twice as common in women than in men.
#
# --- Chunk 143 ---
# source=tmjDoc11 page=1 type=NarrativeText section=None
# Scientists from the National Institute of Dental and Craniofacial Research (NIDCR) are looking for answers to what causes these disorders and how best to treat them. More scientific evidence is needed to show which treatments work and which don’t.
#
# --- Chunk 144 ---
# source=tmjDoc11 page=1 type=NarrativeText section=None
# Until there is science-based evidence to help health care providers make sound treatment decisions, NIDCR suggests the following:
#
# --- Chunk 145 ---
# source=tmjDoc11 page=1 type=ListItem section=None
# = Check with your dentist or doctor, who may have you try simple steps first. It may be helpful to eat soft foods, apply heat or cold to the face in combination with exercises to gently stretch or strengthen jaw muscles, and reduce habits such as jaw clenching, gum chewing, or nail biting. Short-term use of over-the- counter pain medicines may also provide relief.
#
# --- Chunk 146 ---
# source=tmjDoc11 page=1 type=NarrativeText section=None
# N | H National Institute of Dental and Craniofacial Research
#
# --- Chunk 147 ---
# source=tmjDoc11 page=1 type=ListItem section=None
# = Avoid treatments that cause permanent changes in the teeth and bite (occlusal treatments). Such treatments include placing crowns on teeth, grinding down teeth, or using orthodontics to change the position of some or all teeth. These do not work and can worsen the problem.
#
# --- Chunk 148 ---
# source=tmjDoc11 page=1 type=NarrativeText section=None
# National Institute of Dental and Craniofacial Research 1-866-232-4528 www.nidcr.nih.gov
#
# --- Chunk 149 ---
# source=tmjDoc11 page=1 type=NarrativeText section=None
# This information is not copyrighted. Make as many photocopies as you need.
#
# --- Chunk 150 ---
# source=tmjDoc11 page=1 type=ListItem section=None
# = Avoid, when possible, treatments that involve going into the chewing muscles or the temporomandibular joints with a needle or other instrument. Before considering any procedure that goes into your chewing muscles or jaw joints, get opinions from more than one doctor, and completely understand the risks. If open surgery is recommended, such as placing TMJ implants, get an opinion from a surgeon who specializes in treating TMDs.
#
# --- Chunk 151 ---
# source=tmjDoc11 page=1 type=NarrativeText section=None
# Treatment may involve various health care professionals, including doctors, dentists, physical therapists, psychologists, and others. Orofacial pain clinics at medical or dental schools are often a good source of advice.
#
# --- Chunk 152 ---
# source=tmjDoc11 page=1 type=NarrativeText section=None
# For the latest information on TMD visit www.nidcr.nih.gov/health-info/tmd.
#
# --- Chunk 153 ---
# source=tmjDoc2 page=1 type=NarrativeText section=None
# = An official website of the United States government Here’s how you know
#
# --- Chunk 154 ---
# source=tmjDoc2 page=1 type=Title section=None
# National Institute of Dental and Craniofacial Research
#
# --- Chunk 155 ---
# source=tmjDoc2 page=1 type=NarrativeText section=None
# The most common cause of jaw pain is a group of conditions called temporomandibular disorders (TMDs). These disorders can lead to ongoing or repeated pain and difficulty moving the jaw, affecting the joint, nearby muscles, and supporting tissues. In addition, TMDs can occur alone, or with other medical conditions such as migraines, back pain, sleep problems, fibromyalgia, arthritis, and irritable bowel syndrome. While research on TMDs is ongoing, larger nationwide longitudinal studies are needed to better understand TMDs and how they affect people.
#
# --- Chunk 156 ---
# source=tmjDoc2 page=1 type=NarrativeText section=None
# TMDs are the second most commonly occurring musculoskeletal condition resulting in pain and disability (after chronic low back pain). TMD affects about 5% of adults in the U.S., but .«s number can vary depending on who is studied and how ~ wes so
#
# --- Chunk 157 ---
# source=tmjDoc2 page=1 type=UncategorizedText section=None
# measured. TMD can be a temporary problem that goes _—_ Was this page helpful?
#
# --- Chunk 158 ---
# source=tmjDoc2 page=1 type=UncategorizedText section=None
# lasting (chronic) condition. Unusual for chronic pain co
#
# --- Chunk 159 ---
# source=tmjDoc2 page=1 type=UncategorizedText section=None
# higher among young persons between the ages of 20 ar
#
# --- Chunk 160 ---
# source=tmjDoc2 page=1 type=UncategorizedText section=None
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Chunk 161 ---
# source=tmjDoc2 page=2 type=NarrativeText section=None
# Assessing TMDs in a research setting is complex. TMDs are often measured by asking people about symptoms such as muscle, joint, facial or jaw pain, difficulty chewing, and joint sounds. However, variation in the assessment and reporting of TMDs makes it difficult to determine its precise prevalence.
#
# --- Chunk 162 ---
# source=tmjDoc2 page=2 type=NarrativeText section=None
# Table 1 presents results from U.S. studies reporting the prevalence of jaw pain along with the methods of measurement.
#
# --- Chunk 163 ---
# source=tmjDoc2 page=2 type=Table section=None
# Source Pub. Study Stud ucy Measure Year Population Design Lipton et al (1), National Health Interview Survey <https://pubmed.ncbi.nlm.nih.gov/8409001/> 1993 U.S adult civilians Cross-sectional national household interview survey (self-reported questionnaires) (n=42,370) "During the past 6 months, pain in the jaw joint or in front of the ear" more than once. 6-month prevalence All: 5.3% Men: 3.5% Women: 6.9% Prevalance of Jaw Pain
#
# --- Chunk 164 ---
# source=tmjDoc2 page=2 type=UncategorizedText section=None
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Chunk 165 ---
# source=tmjDoc2 page=3 type=UncategorizedText section=None
# Pub. Study ; Study Measure oflew Year Population Design Pain
#
# --- Chunk 166 ---
# source=tmjDoc2 page=3 type=UncategorizedText section=None
# interview survey (self-reported questionnaires) (n=189,992)
#
# --- Chunk 167 ---
# source=tmjDoc2 page=3 type=NarrativeText section=None
# "Jaw joint or in front of ear, pain or aching, past 30 days"
#
# --- Chunk 168 ---
# source=tmjDoc2 page=3 type=UncategorizedText section=None
# "Jaw joint or in front of ear, how many days had pain or aching, past 30 days" ¥ ; P &P ¥ Baseline prevalence
#
# --- Chunk 169 ---
# source=tmjDoc2 page=3 type=UncategorizedText section=None
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Chunk 170 ---
# source=tmjDoc2 page=4 type=UncategorizedText section=None
# Pub. Study . Study Measure oflew Year Population Design Pain
#
# --- Chunk 171 ---
# source=tmjDoc2 page=4 type=UncategorizedText section=None
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Chunk 172 ---
# source=tmjDoc2 page=5 type=Table section=None
# Pub. Study Study Prevalance Source . . Measure of Jaw Year Population Design Pain Yost et al (5), National Health Interview Survey <https://www.ncbi.nlm.nih.gov/books/nbk558001/> 2020 U.S. adults, age 18 to 74 Cross-sectional national household interview survey (face-to-face, computer- assisted personal interviews) (n=52,159) Jaw or face pain that lasted 21 day in the past 3 months 3-month prevalence All: 4.8% Men: 3.2% Women: 6.2% Combined: 18-24: 4.2% 25-34: 4.9% 35-44: 5.2% 45-54: 5.4% 55-64: 5.1% 65-74: 3.7%
#
# --- Chunk 173 ---
# source=tmjDoc2 page=5 type=Title section=None
# Treatment Needs and Financial Costs Associated with TMDs
#
# --- Chunk 174 ---
# source=tmjDoc2 page=5 type=NarrativeText section=None
# Treating TMDs can be costly, and the condition often affects a person’s daily comfort and quality of life. There is no single treatment for TMDs as it can have many different causes and symptoms. Treatments need to match the individual patient’s needs. Treatment options re’ ~¢ from simple approaches such as self-care, pain medication, and physical therapy, to more serious treatments like surgery. Further advances in TM i
#
# --- Chunk 175 ---
# source=tmjDoc2 page=5 type=UncategorizedText section=None
# 2 to enhance the quality of care for individuals with TMDs Was this page helpful?
#
# --- Chunk 176 ---
# source=tmjDoc2 page=5 type=NarrativeText section=None
# Earlier studies suggest that people with TMDs have dou those without it. A small proportion of individuals with portion of the total health care costs associated withth needed to better understand current health care practi: . i coverage, and the long-term needs of people living with
#
# --- Chunk 177 ---
# source=tmjDoc2 page=5 type=NarrativeText section=None
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Chunk 178 ---
# source=tmjDoc2 page=6 type=Title section=None
# Table 2: Financial Costs Associated with TMD in the U.S.
#
# --- Chunk 179 ---
# source=tmjDoc2 page=6 type=NarrativeText section=None
# Table 2 presents results from U.S.-based studies that examined TMD treatment costs.
#
# --- Chunk 180 ---
# source=tmjDoc2 page=6 type=Table section=None
# Pub. Study Source . Year Population Shimshak and DeFuria (6) 1998 Patientsin <https://pubmed.ncbi.nlm.nih.gov/9852811/> aclaims database of a large New England managed care organization Stud “y Measure Results Design Cross- Overall Patients with sectional 1994 health TMD used study of care costs more health claims data ofTMDvs. — careservices from one nonTMD and had year (1994) patients higher (n=1,713 associated cases and costs than 532,485 patients unmatched without a TMD controls) claim TMD patients / non-TMD patients All inpatient claims (per 1,000 admissions): 107.4 / 80.7 All costs per patient: $936 / $517 All inpatient claims excluding TMD cla (per 1.000
#
# --- Chunk 181 ---
# source=tmjDoc2 page=6 type=UncategorizedText section=None
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Chunk 182 ---
# source=tmjDoc2 page=7 type=Table section=None
# Source Pub, — Study . Study Measure Results Year Population Design White et al (7) 2001 TMD Matched Compared TMD cases <https://pubmed.ncbi.nlm.nih.gov/11443827/> patients and case- the useand overall used matched control cost of significantly controls study medical more health enrolledina (n=8,801 anddental services and largehealth casesand = care had 1.6 times maintenance 8,801 services for higher costs organization matched TMD for all services controls) patients than controls and Female TMD matched cases had controls higher costs than the male TMD cases Cases / Controls Mean TMD clinic visits: 3.26 / N/A Mean dental visits: 7.46 / 5.28 Mean pharmacy dispensings: 61.69 / 35.91 Mean outpatient visits: 4. /
#
# --- Chunk 183 ---
# source=tmjDoc2 page=7 type=UncategorizedText section=None
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Chunk 184 ---
# source=tmjDoc2 page=8 type=Table section=None
# Pub. Study Study . . Measure Results Year Population Design Source Mean outside claim/referral Inpatient: 0.09 / 0.08 Outpatient: 2.66 / 2.14
#
# --- Chunk 185 ---
# source=tmjDoc2 page=8 type=ListItem section=None
# Health Info: Temporomandibular Disorders <https://www.nidcr.nih.gov/health-info/tmd>
#
# --- Chunk 186 ---
# source=tmjDoc2 page=8 type=ListItem section=None
# e Learn more about TMD research supported by NIDCR: Research Investments and Advances <https://www.nidcr.nih.gov/grants-funding/funded-research/research-investments-
#
# --- Chunk 187 ---
# source=tmjDoc2 page=8 type=ListItem section=None
# 1. Lipton JA, Ship JA, Larach-Robinson D. Estimated prevalence and distribution of reported orofacial pain in the United States <https://pubmed.ncbi.nlm.nih.gov/8409001/>. J Am Dent Assoc. 1993 Oct;124(10):115-21. doi: 10.14219/jada.archive.1993.0200.
#
# --- Chunk 188 ---
# source=tmjDoc2 page=8 type=ListItem section=None
# 2. Plesh O, Adams SH, Gansky SA. Racial/ethnic and gender prevalences in reported common pains in a national sample <https://pubmed.ncbi.nlm.nih.gov/21359234/>. J Orofac Pain. 2011 Winter;25(1):25-31.
#
# --- Chunk 189 ---
# source=tmjDoc2 page=8 type=ListItem section=None
# 3. Alkhubaizi Q, Sorkin JD, Hochberg MC, Gordon SM. Risk factors for facial pain: Data from the Osteoarthritis Initiative Study <https://pubmed.ncbi.nlm.nih.gov/30211397/>. J Dent Oral Biol. 2017;2(3):1033. Epub 2017 Feb 9.
#
# --- Chunk 190 ---
# source=tmjDoc2 page=8 type=ListItem section=None
# 4. National Academies of Sciences, Engineering, and Medicine; Health and Medicine Division; Board on Health Care Services; Board on Health Sciences Policy; Committee on Temporomandibular Disorders (TMDs): From Research Discoveries to Clinical Treatment. Appendix C, Prevalence, impact, and costs of treatment for temporomandibular disorders <https://www.ncbi.nlm.nih.gov/books/nbk557996/>. In: Yost O, Liverman CT, English R, editors. Temporomandibular disorders: Priorities for research and care. Washington (DC): National Academies Press (US); 2020 Mar 12.
#
# --- Chunk 191 ---
# source=tmjDoc2 page=8 type=ListItem section=None
# 5. National Academies of Sciences, Engineering, and Medicine; Health and Medicine Division; Board on Heaun Care Services; Board on Health Sciences Policy; Committee on
#
# --- Chunk 192 ---
# source=tmjDoc2 page=8 type=UncategorizedText section=None
# Research Discoveries to Clinical Treatment. Chapter 3, Individ' Was this page helpful?
#
# --- Chunk 193 ---
# source=tmjDoc2 page=8 type=UncategorizedText section=None
# <https://www.ncbi.nlm.nih.gov/books/nbk558001/>. In: Yost O, Liverm
#
# --- Chunk 194 ---
# source=tmjDoc2 page=8 type=UncategorizedText section=None
# disorders: Priorities for research and care. Washington (DC): Na
#
# ...
#
# --- Chunk 361 ---
# source=tmjDoc7 page=2 type=ListItem section=None
# ¢ Habits such as gum chewing, nail biting, and grinding or clenching of teeth.
#
# --- Chunk 362 ---
# source=tmjDoc7 page=2 type=ListItem section=None
# ¢ Stress, post-traumatic stress disorder, anxiety or depression.
#
# --- Chunk 363 ---
# source=tmjDoc7 page=2 type=ListItem section=None
# ¢ Conditions such as fibromyalgia, ankylosing spondylitis and sleep disturbances.
#
# --- Chunk 364 ---
# source=tmjDoc7 page=2 type=NarrativeText section=None
# Any use of this site constitutes your agreement to the Terms and Conditions and Privacy Policy linked below.
#
# --- Chunk 365 ---
# source=tmjDoc7 page=2 type=NarrativeText section=None
# Mayo Clinic is a nonprofit organization and proceeds from Web advertising help support our mission. Mayo Clinic does not endorse any of the third party products and services advertised.
#
# --- Chunk 366 ---
# source=tmjDoc7 page=2 type=NarrativeText section=None
# Asingle copy of these materials may be reprinted for noncommercial personal use only. "Mayo," "Mayo Clinic," "MayoClinic.org," "Mayo Clinic Healthy Living," and the triple-shield Clinic logo are trademarks of Mayo Foundation for Medical Education and Research.
#
# --- Chunk 367 ---
# source=tmjDoc7 page=2 type=NarrativeText section=None
# © 1998-2025 Mayo Foundation for Medical Education and Research (MFMER). All rights reserved.
#
# --- Chunk 368 ---
# source=tmjDoc7 page=2 type=UncategorizedText section=None
# https://www.mayoclinic.org/diseases-conditions/tmj/symptoms-causes/syc-20350941?p=1
#
# --- Chunk 369 ---
# source=tmjDoc8 page=1 type=NarrativeText section=None
# Panoramic dental x-ray uses a very small dose of ionizing radiation to capture the entire mouth in one image. It is commonly performed by dentists and oral surgeons in everyday practice and may be used to plan treatment for dentures, braces, extractions and implants.
#
# --- Chunk 370 ---
# source=tmjDoc8 page=1 type=NarrativeText section=None
# This exam requires little to no special preparation. Tell your doctor if there is a possibility you are pregnant. Remove any jewelry, eye glasses or metal objects that might interfere with the x-ray images. You will be asked to wear a lead apron to protect the rest of your body from any radiation exposure.
#
# --- Chunk 371 ---
# source=tmjDoc8 page=1 type=NarrativeText section=None
# Panoramic radiography, also called panoramic x-ray, is a two-dimensional (2-D) dental x-ray examination that captures the entire mouth in a single image, including the teeth, upper and lower jaws, surrounding structures and tissues.
#
# --- Chunk 372 ---
# source=tmjDoc8 page=1 type=NarrativeText section=None
# The jaw is a curved structure similar to that of a horseshoe. However, the panoramic x-ray produces a flat image of the curved structure. It usually provides details of the bones and teeth.
#
# --- Chunk 373 ---
# source=tmjDoc8 page=1 type=NarrativeText section=None
# An x-ray exam helps doctors diagnose and treat medical conditions. It exposes you to a small dose of ionizing radiation to produce pictures of the inside of the body. X-rays are the oldest and most often used form of medical imaging.
#
# --- Chunk 374 ---
# source=tmjDoc8 page=1 type=NarrativeText section=None
# Unlike a traditional intraoral x-ray where the film/x-ray detector is placed inside of the mouth, the film for a panoramic x-ray is contained inside of the machine.
#
# --- Chunk 375 ---
# source=tmjDoc8 page=1 type=NarrativeText section=None
# A panoramic x-ray is a commonly performed examination by dentists and oral surgeons in everyday practice and is an important diagnostic tool. It covers a wider area than a conventional intraoral x-ray and, as a result, provides valuable information about the maxillary sinuses, tooth positioning and other bone abnormalities. This examination is also used to plan treatment for full and partial dentures, braces, extractions and implants.
#
# --- Chunk 376 ---
# source=tmjDoc8 page=1 type=NarrativeText section=None
# https://www.radiologyinfo.org/en/info/panoramic-xray
#
# --- Chunk 377 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# A panoramic x-ray can also reveal dental and medical problems such as:
#
# --- Chunk 378 ---
# source=tmjDoc8 page=2 type=ListItem section=None
# e jaw disorders (also known as temporomandibular joint or TMJ disorders)
#
# --- Chunk 379 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# A panoramic x-ray examination requires no special preparation.
#
# --- Chunk 380 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# You may be asked to wear a lead apron as a safety precaution to protect the rest of your body from any radiation exposure that may scatter from the panoramic x-ray beam. You may also be asked to remove your jewelry from the region being imaged, eye glasses and any metal objects that might interfere with the x-ray images.
#
# --- Chunk 381 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# Women should always inform their dentist or oral surgeon if there is any possibility that they are pregnant. Many imaging tests are not performed during pregnancy so as not to expose the fetus to radiation. If an x-ray is necessary, precautions will be taken to minimize radiation exposure to the baby. See the Radiation Safety page for more information about pregnancy and x-rays.
#
# --- Chunk 382 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# A panoramic x-ray machine consists of two sides. An x-ray tube is mounted on one side and the x-ray film or a detector on the opposite side. The patient's head is positioned with chin, forehead and side rests. The patient may be provided with a bite blocker to open the mouth slightly for a clearer picture.
#
# --- Chunk 383 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# X-rays are a form of radiation like light or radio waves. X-rays pass through most objects, including the body. The technologist carefully aims the x-ray beam at the area of interest. The machine produces a small burst of radiation that passes through your body. The radiation records an image on photographic film or a special detector.
#
# --- Chunk 384 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# During a panoramic x-ray examination, the x-ray tube rotates in a semicircle around the patient's head, starting at one side of the jaw and ending at the other side.
#
# --- Chunk 385 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# Rather than relying on film placed inside the mouth, a panoramic x-ray machine projects a beam through the patient onto film or a detector rotating opposite the x-ray tube.
#
# --- Chunk 386 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# Most x-ray images are electronically stored digital files. Your doctor can easily access these stored images to diagnose and manage your condition.
#
# --- Chunk 387 ---
# source=tmjDoc8 page=2 type=NarrativeText section=None
# https://www.radiologyinfo.org/en/info/panoramic-xray
#
# --- Chunk 388 ---
# source=tmjDoc8 page=3 type=NarrativeText section=None
# The digital format also allows the dentist to adjust and change the contrast, brightness and darkness of the image for better visualization of certain structures and tissues. Images on film cannot be adjusted or changed.
#
# --- Chunk 389 ---
# source=tmjDoc8 page=3 type=NarrativeText section=None
# First, you will be situated in the center of the unit where the technician will carefully position and secure your head. The unit can be adjusted to accommodate a patient standing or sitting in a wheelchair. A bite- blocker is then placed in your mouth to ensure proper alignment of the teeth. Correct placement of the teeth and head is important for obtaining a clear image.
#
# --- Chunk 390 ---
# source=tmjDoc8 page=3 type=NarrativeText section=None
# You will be asked to remain very still while the rotating arm travels in a semicircle around the perimeter of your head and the images are being taken. This can typically last between 12 to 20 seconds.
#
# --- Chunk 391 ---
# source=tmjDoc8 page=3 type=Title section=None
# What will | experience during and after the procedure?
#
# --- Chunk 392 ---
# source=tmjDoc8 page=3 type=NarrativeText section=None
# A panoramic x-ray exam is painless, fast and easy to perform. It may be recommended over intraoral x- rays for patients that have a sensitive gag reflex.
#
# --- Chunk 393 ---
# source=tmjDoc8 page=3 type=ListItem section=None
# ¢ No radiation stays in your body after an x-ray exam.
#
# --- Chunk 394 ---
# source=tmjDoc8 page=3 type=ListItem section=None
# X-rays usually have no side effects in the typical diagnostic range for this exam.
#
# --- Chunk 395 ---
# source=tmjDoc8 page=3 type=ListItem section=None
# e Panoramic dental x-ray can provide valuable diagnostic information to guide your dentist or oral surgeon to treat your dental and oral disease.
#
# --- Chunk 396 ---
# source=tmjDoc8 page=3 type=ListItem section=None
# e Panoramic x-rays can be used for very young children since the film does not have to be placed inside the mouth.
#
# --- Chunk 397 ---
# source=tmjDoc8 page=3 type=ListItem section=None
# ¢ Women should always inform their dentist or oral surgeon if there is any possibility that they are pregnant. See the Radiation Safety page for more information about pregnancy and x-rays.
#
# --- Chunk 398 ---
# source=tmjDoc8 page=3 type=NarrativeText section=None
# A panoramic x-ray does not provide precise and detailed information about each individual tooth or soft tissues, such as the muscles. It is generally used as an initial evaluation of the bones and teeth. Because your mouth is curved, the panoramic x-ray can sometimes create a slightly blurry image where accurate measurements of your teeth and jaw are not possible. If your dentist or surgeon needs more information, a computed tomography (CT) scan or magnetic resonance imaging (MRI) may be ordered. https://www.radiologyinfo.org/en/info/panoramic-xray
#
# --- Chunk 399 ---
# source=tmjDoc8 page=4 type=NarrativeText section=None
# This may include Dental Cone Beam CT, an imaging exam developed specifically for this part of the body.
#
# --- Chunk 400 ---
# source=tmjDoc8 page=4 type=NarrativeText section=None
# National Institute of Dental and Craniofacial Research: TMJ Disorders (https://www.nidcr.nih.gov/health- info/tmj)
#
# --- Chunk 401 ---
# source=tmjDoc8 page=4 type=NarrativeText section=None
# Radiologyinfo.org is not a medical facility. Please contact your physician with specific medical questions or for a referral to a radiologist or other physician. To locate a medical imaging or radiation oncology provider in your community, you can search the ACR-accredited facilities database (https://www.acraccreditation.org/accredited-facility-search) .
#
# --- Chunk 402 ---
# source=tmjDoc8 page=4 type=NarrativeText section=None
# This website does not provide cost information. The costs for specific medical imaging tests, treatments and procedures may vary by geographic region. Discuss the fees associated with your prescribed procedure with your doctor, the medical facility staff and/or your insurance provider to get a better understanding of the possible charges you will incur.
#
# --- Chunk 403 ---
# source=tmjDoc8 page=4 type=NarrativeText section=None
# Web page review process: This Web page is reviewed regularly by a physician with expertise in the medical area presented and is further reviewed by committees from the Radiological Society of North America (RSNA) and the American College of Radiology (ACR), comprising physicians with expertise in several radiologic areas.
#
# --- Chunk 404 ---
# source=tmjDoc8 page=4 type=NarrativeText section=None
# Outside links: For the convenience of our users, Radiologyinfo.org provides links to relevant websites. Radiologyinfo.org, RSNA and ACR are not responsible for the content contained on the web pages found at these links.
#
# --- Chunk 405 ---
# source=tmjDoc8 page=4 type=NarrativeText section=None
# Copyright © 2025 Radiological Society of North America, Inc. (RSNA). help ensure current and accurate information, we do not permit copying but encourage linking to this
#
# --- Chunk 406 ---
# source=tmjDoc8 page=4 type=UncategorizedText section=None
# https://www.radiologyinfo.org/en/info/panoramic-xray
#
# --- Chunk 407 ---
# source=tmjDoc9 page=1 type=NarrativeText section=None
# Temporomandibular disorders (TMD) refer to an orofacial (face, head, or neck) pain condition in which pain and discomfort affect the temporomandibular joint (TMJ), the muscles, or the contiguous tissue components.
#
# --- Chunk 408 ---
# source=tmjDoc9 page=1 type=ListItem section=None
# ¢ Postmarket surveillance study information, including study results (/medical- devices/temporomandibular-disorders-tmd-devices/fdas-role-approving-tmj-implants- and-monitoring-their-safety#surveillance)
#
# --- Chunk 409 ---
# source=tmjDoc9 page=1 type=ListItem section=None
# e FDA-approved TMJ implants (/medical-devices/temporomandibular-disorders-tmd- devices/fdas-role-approving-tmj-implants-and-monitoring-their-safety#fdaapproved),
#
# --- Chunk 410 ---
# source=tmjDoc9 page=1 type=NarrativeText section=None
# The TMJ is the part of the lower jaw, in front of the ear where the lower jaw connects to the to the skull. There is a TMJ on each side of the jaw. The TMJ is composed of three parts.
#
# --- Chunk 411 ---
# source=tmjDoc9 page=1 type=ListItem section=None
# e Mandibular condyle - the part of the joint located in the lower jaw.
#
# --- Chunk 412 ---
# source=tmjDoc9 page=1 type=ListItem section=None
# * Glenoid fossa - the part of the joint located at the base of the skull.
#
# --- Chunk 413 ---
# source=tmjDoc9 page=1 type=ListItem section=None
# e Meniscus - a small disc-shaped piece of cartilage, which serves as a cushion between the mandibular condyle and glenoid fossa.
#
# --- Chunk 414 ---
# source=tmjDoc9 page=1 type=NarrativeText section=None
# For some patients, the pain in the TMJ is severe and unrelenting. Symptoms can include clicking or popping of the TM4J, pain in or around the TMJ and muscles, locking or limited opening of the mouth, headaches, pain behind the eyes, dizziness, earaches or ringing in
#
# --- Chunk 415 ---
# source=tmjDoc9 page=1 type=NarrativeText section=None
# https://www.fda.gov/medical-devices/dental-devices/temporomandibular-disorders-tmd-devices
#
# --- Chunk 416 ---
# source=tmjDoc9 page=2 type=UncategorizedText section=None
# the ears, clenching or grinding of the NIH/NIDGR (https:/www.nidcr.nih.gov/health-info/tmj/more-info)
#
# --- Chunk 417 ---
# source=tmjDoc9 page=2 type=NarrativeText section=None
# TMD is a complex medical condition which can be difficult to treat.
#
# --- Chunk 418 ---
# source=tmjDoc9 page=2 type=ListItem section=None
# ¢ Behavioral changes (for example, avoiding gum chewing)
#
# --- Chunk 419 ---
# source=tmjDoc9 page=2 type=ListItem section=None
# e Devices that may help relieve pain, such as ice packs
#
# --- Chunk 420 ---
# source=tmjDoc9 page=2 type=ListItem section=None
# e Bite guards (also known as occlusal splints or nightguards)
#
# --- Chunk 421 ---
# source=tmjDoc9 page=2 type=ListItem section=None
# e Laser devices used to relieve muscle-related jaw pain
#
# --- Chunk 422 ---
# source=tmjDoc9 page=2 type=NarrativeText section=None
# Surgical treatment options, which are more invasive, include:
#
# --- Chunk 423 ---
# source=tmjDoc9 page=2 type=Title section=None
# IMJ implants (/medical-devices/temporomandibular-disorders-tmd-
#
# --- Chunk 424 ---
# source=tmjDoc9 page=2 type=NarrativeText section=None
# devices/temporomandibular-joint-tmj-implants) are intended to be implanted in the jaw to replace all or part of the temporomandibular joint. The purpose of these types of implants is to restore TMJ function, including opening and closing the mouth and chewing.
#
# --- Chunk 425 ---
# source=tmjDoc9 page=2 type=Image section=None
# Was this page helpful? * (required) Yes No Submit = An official form of the United States government. Provided by Touchpoints
#
# --- Chunk 426 ---
# source=tmjDoc9 page=2 type=UncategorizedText section=None
# https://www.fda.gov/medical-devices/dental-devices/temporomandibular-disorders-tmd-devices

# %%
#Create embeddings
embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
)

# %%
#Create Pinecone vector store
vector_store = PineconeVectorStore(
    index_name=index_name,
    embedding=embeddings
)

# %%
#Add documents to the vector store and persist vector store
vector_store.add_documents(chunked_docs)
# Out:
# ['31207198-5589-4927-ab41-8cd95c9b614a',
#  'ba7f80a4-9ee1-44ec-bb2f-933725d71fb1',
#  'b8580911-30f6-491a-86bb-76133eb72cb5',
#  'c62d8c23-d596-48df-bc61-6b6ff985bfb2',
#  '928f80e7-bf54-46b1-af5d-e4a5734ef432',
#  '875d90a8-e909-4371-aae7-8e9640b14f3c',
#  '6dfd9790-ded6-412b-917a-6f7ca02eafe3',
#  '68f199a5-e249-45b4-b1c4-1ba08c0ebe0b',
#  'bdd866df-7c4f-4493-b21d-0d153540b4cb',
#  'a8e0432f-655a-419d-910d-e63f60f8470e',
#  'e2393a95-d69d-48a1-8878-69af95cd911d',
#  '7c59ee7f-e561-4002-bf76-3274d312a8ba',
#  '964add7c-a0f8-47d7-9085-116291105f93',
#  '68fd9ab8-9459-4b4d-afbf-35d5f0b28ec9',
#  'abdc8b86-577c-421d-9bb4-c98f01fb91bf',
#  '9768055c-9887-46e4-8f5d-41a3f31b3b75',
#  '29d277f4-23eb-49dc-902f-b067bcfa9933',
#  '30a49c6d-8b64-45ab-a670-56e189b70e2b',
#  '5a821778-e188-40ac-9350-e80785efa48f',
#  'be69f710-81be-4b93-bd34-6f80a59c2950',
#  '47f44bf6-28e3-4363-b99b-88f717ccd481',
#  'e46be0cf-8755-4d45-8e64-58a7c20fd54d',
#  '3264544f-d17e-4d07-bf20-ec3f0908fb6f',
#  '84e9697d-5c20-4bbe-9297-078ee6b24d35',
#  'cbbd5d98-868e-4b70-9982-1293798cef8e',
#  '91cb8cda-7972-44c2-94e3-77a003899df5',
#  'e8ad1e82-acb0-433e-9de8-11443369b497',
#  '16498061-9db0-4966-91e5-10e225cc2560',
#  '1d473932-b5a5-4430-8b3c-b1bcd535d5ae',
#  'd659726e-b62d-49c7-91cb-1d6c83ca3353',
#  '4036f6cd-663d-4ca5-8801-8d33db78b2f5',
#  '36639377-9da9-4b8a-8a4e-91c44e8425a3',
#  'bb225aaf-be58-4f48-b202-75d6af19490b',
#  '216b32fb-5c0e-4dbd-aeff-c3c396883b93',
#  '68d705be-6a4b-4d23-83d3-5e76feb4e3af',
#  'a9ac3fe9-7711-4c5b-af38-914eac01b58d',
#  'd934012a-0b8f-4cc7-9461-79a6589954bc',
#  'd9a72a52-de06-429f-9e65-8922d206fbff',
#  '1d17423e-ad5d-43c6-b456-6222e1ecc613',
#  '32323e92-281d-4224-b283-d9b808399c29',
#  '5644b28a-4658-47fa-8967-f680999aec4c',
#  'cc2f95e0-f74f-4e15-b4f2-6d2ff9fbe243',
#  '59af203f-6641-4d09-a07b-6544269ca3a0',
#  '76184719-2b37-4459-900a-fe67cb82de37',
#  'c941f26c-146c-4219-87f3-4b4f7d61ea92',
#  '1417cd2b-304b-4991-ab0d-6bee8b6083c6',
#  '8cf2c363-5a0e-4e80-9e63-bfff44d778e9',
#  '6730d156-b088-4e0d-9bd4-2851516a7733',
#  '8102443a-a152-4243-824a-914e1692dd03',
#  'cacac138-15ad-40d6-941a-4ad921e7ddbc',
#  '8b9e5e9a-5b0b-4b75-9437-a75dfde5dad1',
#  'c78cd912-35b0-4e43-8b37-4dbaa7451bfd',
#  '401a6c2e-e052-4cc8-b058-549f25f19bd5',
#  'f2f91470-65f5-4e92-a5a3-155e6cbb4342',
#  'b41e4294-6192-4c88-9baa-c379d7d7d753',
#  '8f21656d-5eae-48bb-8a7d-2b76098ad938',
#  '74b80d0c-9d6c-4dab-9326-556be253e9c5',
#  'd9688501-1c35-46da-82a4-40ca14e569b0',
#  '6e887430-61b1-4f17-804e-6b5876ac1c70',
#  'dd7a4e27-9196-4642-ac98-49af95ccb22f',
#  'f9335f14-0b44-4ef1-b882-022c37a677b5',
#  'b39a959b-7645-4e04-9429-406b4b9ace61',
#  '737dd4f8-b1a4-47c9-be2f-34545f409ab7',
#  '7e45a780-fbb7-4514-88fe-a0ef7870f73b',
#  '6fd9cd67-3efd-4fc7-9cf7-bbd185e186ec',
#  '83cc3c01-0d20-4840-b83a-ed8bd3ab17d1',
#  'dea8e860-b00e-43da-af74-cedebb0d9fb2',
#  'b979ebfe-87f5-41f4-89f6-a5d086770e1e',
#  '1ded63a6-5db6-4882-a5fd-21e35401b53c',
#  '8fd7089d-e8b0-4a92-8a09-709ecad78458',
#  '61959361-0ce7-42ba-a8ef-31fd2cee5c6b',
#  '99bf6da4-8de7-4886-ba28-bc0db693d2e8',
#  'eaa67982-7aba-49e5-ba35-af56c2e245ed',
#  '9a60105e-0a35-4823-8057-84a5c135306d',
#  '4fb9f6a4-d6d0-4105-832e-ee38289121c7',
#  '9cdb8a97-db5f-4127-90dd-35b3a46e2bcd',
#  'bb563de7-f441-4429-8ea8-79b744f1f314',
#  '244d0ff8-f6ac-4849-bf98-4fa0939cc361',
#  '986d7f2f-19e0-4d0e-9d4a-c405ff39f434',
#  '8f7afb64-5272-4982-98b4-0c4905717b76',
#  '454e8c68-0718-4ffd-87a7-1e69f25a7676',
#  'b919f760-df88-4d55-99f6-5de3f0bc3624',
#  '0346818c-2984-4929-8eb0-6eb4fb5dae16',
#  '3cbb85ff-2945-45e4-af17-95a9b6ed54b0',
#  '220a7554-8252-401a-846a-d1f06fb5e328',
#  '44cfc671-0bdd-4824-b4e4-4d4f25862652',
#  'd4c6c01a-75e1-4e12-babe-88286345147b',
#  '564cbef9-0c05-4e4a-a966-62a752915c46',
#  '60b8684a-5dbf-4985-aa09-335ae38ab766',
#  '02b9ce02-3d78-4186-9202-547fa93b872d',
#  '51b30bb5-8b1a-4b42-85ca-abb797f30700',
#  'ce4979a8-4ea6-4b44-a912-039ed797efb1',
#  '5cb6e034-fa8e-47dd-8f3d-90a79f40548f',
#  'b113e5e1-5f19-4ea3-9b96-ef94b6c2eff8',
#  'ae180f77-08c1-4864-b67a-ad54a232dffc',
#  'e912633d-bdd2-4e7f-8ee0-8c1f942a02c7',
#  '8e52cdb5-1af9-48b1-aa64-2b2bebf59213',
#  'd5d24bd0-6379-4fce-a326-d68b350deca9',
#  'd80f2f0a-2c27-4dc1-a535-e2dbc690e4d0',
#  'b2b3bf30-a287-496f-8f0b-5f292d467a8d',
#  '0047b37b-78f5-4421-b288-0c3c4f51a406',
#  'e6cc9964-1978-40d9-b1aa-bdbd03202b46',
#  'f5d33790-6881-416b-9c49-e7fe912c5c92',
#  'd04b37ad-ffe9-4219-b731-da1dc90cf719',
#  'f22d6f9c-6fb5-4daf-9a16-1b291efd7e43',
#  '5722b047-f2ec-4715-929a-bcefee15c7ad',
#  'd45fc062-a101-4ac7-b0f7-8742f75a4271',
#  'bd5ec176-1c2a-42c3-afaa-5bc9a3aee131',
#  'fe9e4266-3b28-44d7-be90-b0e2ae448bee',
#  '11f1fe71-7e39-4b71-ab7e-70e707fbcfa8',
#  'c47101cf-360a-4089-b4c8-3017068dfc3d',
#  '257e13d3-1b72-4d78-8b4f-aa46a9205764',
#  '87bbe247-ce89-4b86-9ac4-f405606447f6',
#  'aa46039b-6749-4abf-913e-d43a0f9eb1a2',
#  'ab2682a2-a077-46a2-9760-b5bcb4cd3ad5',
#  '65ca110a-dac9-4b29-b25f-c3ad9f593452',
#  'ba222f9a-1add-4fee-a491-dc42b140c512',
#  'aa8ee292-b387-4212-b20f-1de75d39c4ee',
#  '6e050f70-79db-4d5a-a40f-f7dd0c2482f9',
#  'f50adb07-0943-444d-a720-4356101c705e',
#  'e181abb5-ee56-4aaa-8073-a40ac21828ec',
#  'deeeb0d6-e7e9-40f9-9850-ade0dc8c5b67',
#  '4f7dc526-eeea-4135-ba74-4156c1539aec',
#  '19be6b0d-49a6-4fa3-bdb3-124fda66c3bd',
#  'e3109f67-0789-4113-83ed-04bf6379347c',
#  '786e5153-8ab9-4e5e-af43-f829bb2c61b2',
#  'fa9d2fb1-abb5-49ae-b3f2-11d3ab7095eb',
#  '59c6dd94-d215-43d0-8a99-044092f25615',
#  '2f962f4f-53bc-4118-bb5f-ee25e62050e1',
#  'be9b79ec-11c5-46f8-99d4-1b0d35f5cd1d',
#  '9c8f9855-efde-4063-a4da-ef1e01bf185a',
#  'dcc20b2c-5045-4590-ad76-2d6642cd48ac',
#  '87385805-948c-4785-a35e-a6b830e66eb5',
#  '4817d0c9-1acc-40c9-8597-57a89750424f',
#  '24bc0f39-3cd7-4106-b1f1-9681a4eabade',
#  'fcdf430d-dbde-4b21-b8b4-288a1d6e9a51',
#  '9152f09e-8a48-4c21-accc-25a0880622a1',
#  'c1312ac8-ad01-49a6-bcfb-e9da86714771',
#  'e3a8fcbb-aced-481b-b15b-566e359120fd',
#  '14b5c46a-f0d9-4fd7-9bf2-37ca4f091a7d',
#  '891f3e72-8665-4c47-9a2f-8e78a36d9ff6',
#  'eca06231-6711-4b8a-a725-c522e1618799',
#  'f8e36776-c413-4157-9b87-5181152602e2',
#  '3e190b2a-2acd-41a7-ada3-050e1a5e4071',
#  'b079d507-d691-4209-8359-a09de2b6847c',
#  '3dcf61f9-dbfb-4f87-afe6-e70a0ade5bc9',
#  'ca355906-1dbd-4510-85c0-f49908c09084',
#  '86e02f19-3022-4aba-bd2e-4b776f101a84',
#  'eb3ab5d7-918b-4d86-a50b-7ceb9f874cf0',
#  'a50425ab-dcee-464c-a9ef-f9223d39df7f',
#  '3813d2f9-2748-4be7-90a1-ad6be1875260',
#  'a49b107c-7e5d-48d7-8e71-418acf35775c',
#  'd259c2ef-b77a-4146-98b6-b3bf256ecdba',
#  'f4cbb9e7-4e82-41ba-9223-a8bad0ad8893',
#  '6835be6c-d621-4651-9cc7-d540c618984d',
#  'a699e62f-eea9-48c9-97d9-e594700d5af5',
#  'ad76d99b-b8c4-472f-a2f2-5eebca0843f5',
#  'f890c790-25f0-4552-9463-5729432e97ef',
#  'd9e6c999-53ef-427e-8e28-79948a6c0dc3',
#  'aab545bf-d4dd-4b48-95cb-774692d785b8',
#  'a0ad6cb8-050d-4ef9-87f3-b79b95d3bb9a',
#  '80707e8e-829e-40e5-b6df-287547577951',
#  '270f53ae-51f3-40c4-9fd1-681e5c1a7fb5',
#  'bb9e65a2-79c8-4419-8729-76c770068c4c',
#  '614a5ad7-602e-4e00-a010-86483a2b6674',
#  '6ea0a5c2-0a52-4349-bbbd-de432683f6b2',
#  'b5a25212-f0fe-4e0a-bb55-d7dca20c1dcc',
#  'e43c65ae-226b-45a4-8419-45b0964c03b5',
#  'cdd828f6-93df-4170-a141-dd7b13d73a64',
#  'af553580-aaa2-446c-9476-3553fb7c5479',
#  '6556e114-4199-40e3-8b61-c927a1ef9d6f',
#  '59e3375f-fb69-4023-ae73-82c250ebc1bf',
#  '6f3f44e4-bbe1-4042-b6fa-e0a06b32506f',
#  '55ad51fd-84d8-424e-9c5b-f3d6d0026df9',
#  'e33e50c1-081a-486d-9d96-0909d1412cbd',
#  '8c6e6103-58cb-4120-8701-9c77488c5606',
#  'fa8802c1-1cf7-4a8c-aac0-1255d9182875',
#  '34dfb361-f936-4f20-be64-77d8d3588a45',
#  '0fbedb07-7dbb-4057-90b4-ccdde38e752a',
#  'dbcb49f5-f8a2-41ea-950c-b7ae4ea97958',
#  '27f43337-12a1-4b09-b365-5c1626bc5851',
#  '8a846685-c9d4-4bc3-9bc0-4f6f820da7c9',
#  'fdae25b5-f0eb-4106-8d73-014773c01ef1',
#  '02e0636a-6853-472c-acee-011aa320c107',
#  'e46ff10a-9073-4f6d-a163-00893913e8b8',
#  'c3aadea2-9e20-4e30-a75f-af1c698d5948',
#  'a1eee633-a225-4f66-ab33-8d9b3264a1ed',
#  'ab2042e2-78cc-4c29-b3ac-7f8452973e35',
#  'c4dcb163-1a09-41fc-ab33-f7606306c009',
#  'eb25ee88-9b80-427a-947e-ebd29b02c211',
#  'b3280701-33fc-4e18-89fe-027537c387b8',
#  'f89540e6-1faf-405d-8b81-7283852f59d4',
#  'b8f14409-35a2-4b50-a401-025c6c5be635',
#  'ba5dd860-e95e-461f-b20f-7c4be5aab83f',
#  '0d9fc32f-02e3-4775-9fa1-a307cf939b8d',
#  'fa05e805-2755-4e19-b1e1-aa1870bfe2e7',
#  '12930676-628a-48d4-bbaa-6d8e81f9c8c2',
#  '74913e79-8ca5-4e43-89f2-9e9030bc486d',
#  '6667c4f0-06ff-4173-a342-a9899d3a605b',
#  '310ad188-8822-4af8-bf20-91b743c2aa39',
#  'e59778d2-490b-412d-ab14-ac3abe3ce1c7',
#  '220d42c7-c53d-4b7a-afba-28f30c9a2ebd',
#  '3b7be0d3-d8da-49e0-8a59-859d2731d592',
#  '490451a2-870b-4310-bc38-fe30dbdcb002',
#  'afd7bf7d-0745-41f4-806f-bdf1b2f238bd',
#  '4e92503a-9bc7-4abe-90ff-20554924bd09',
#  '1cb2537d-1cb2-40bb-8208-222f9aa9444c',
#  '126b8728-b9b5-4d21-99fc-9c573ba300c4',
#  'd4405d0b-a040-442c-b59d-49c1fa42f8e0',
#  '032aa930-5caf-4acf-890b-cdaad850e56e',
#  'f935fc4e-0539-4346-a539-541353250062',
#  '8b942389-d94b-4ce0-9081-b618e9dbdae1',
#  '841d0c65-33eb-4807-a993-4ccce6a321e0',
#  'c67d14ed-2318-4826-928c-d7ad380129c2',
#  '1d77656b-0eee-4dc8-92ca-e829bc08e7bd',
#  'c7ce4b6d-eca7-49b8-bc74-0ef6d573a7cb',
#  '03002314-8a98-4c25-87e0-98a170cb1264',
#  '0d305198-1e77-4f30-b0f0-19413212b1df',
#  '3d2b3a2a-5b9f-4b53-8b41-91cd932575d6',
#  '955fa4c9-53ce-4d03-92fa-82a60292e733',
#  '016bf9b1-f0a1-4451-a360-45d5b0b10f00',
#  '5158bffe-cdcf-4048-86e1-cdc6c8db32f6',
#  'b21726c4-1f1d-4423-91d7-9205fc717a3c',
#  '07d6b7b8-5af0-434f-9572-fc213f21eb66',
#  '359c6fb2-4640-4a46-910c-8479be42d5f4',
#  '967d956b-1acb-4456-a48b-e682767c6f99',
#  'fa4c9f9a-10be-45a5-81cd-dd411d4bcb7e',
#  '3776f071-e382-48b6-92fa-4cc923ee9eef',
#  '5486ef54-83c2-489c-83a1-4af8c71ce0ac',
#  'cbd6d324-8f88-4d98-a56e-48fa89f69945',
#  'e99c3d36-cd77-42e6-b8af-2d953f35d8c9',
#  '995b2f84-4d50-467d-87ee-10b5261a98d9',
#  '7a036fec-3c43-490a-b275-2fb208318ebe',
#  '7e282bf5-70a4-4785-8268-d1478368b0cc',
#  '82ff2192-e0a9-446f-876d-a1da6e66c85a',
#  '98095dad-b005-4073-8481-a196a0c945a0',
#  '3726117d-4f52-4e8e-873d-45885af9d8e3',
#  '3f779a0b-eb83-4477-9cd7-a9920911c6b9',
#  'ae8c9c9c-6cc3-45e8-af65-69895ba4fd3a',
#  'dd35b450-8ba7-4cff-a78a-63832acf269a',
#  'c409e6f8-b6c1-47b7-9a22-62d92d8c2c8a',
#  '432b84f1-4f9e-424d-870c-ef4a7b5acdb1',
#  'c2771517-6b9e-4a68-b17a-e7b6ab093e50',
#  'b2bb5263-0098-44b7-adc6-ba86b55b7a23',
#  '604ba2a4-ebf0-4f11-8875-28ca9dfa2d0a',
#  '3ec3946b-e9cc-4d22-bea9-9cda8b6b8bcd',
#  'eb7058eb-008a-4c91-bd00-b82d904c5165',
#  '4b043d2f-be2d-4b0f-b101-4e28103055d3',
#  'ed7d5823-94d0-4847-b3d5-b171a29c4679',
#  '9f041ed1-9858-4f50-8661-e3e625e01289',
#  '88899718-ce10-45f2-ae4a-2e947b33b3a3',
#  '23807c6d-ccc0-4abe-9f8b-1208f0b043c3',
#  '1683ee97-271a-4b74-8660-13ee3fad37e5',
#  '0b3756a6-a7d0-4572-94b6-5780da14c118',
#  '5292ccbc-b272-49a7-a470-6e76b4e1cf4b',
#  '999c0e2f-6eef-4938-a09c-50eb6a298d98',
#  '358b35d7-f150-4ef2-808e-ceed3b4aeae2',
#  '8b35c21b-94d7-457a-b4c1-a6e4a035f9fd',
#  'c5b9d06e-2777-4fe3-be97-c9726d6142bc',
#  'c843e268-5a6d-4d7b-b735-e844823b7aa1',
#  '9da11197-5356-41c9-a764-e690c32fa340',
#  '111ad3b1-1544-4efe-976b-f1f27e312540',
#  '32620234-d3b2-4280-b101-6e134ba1c73b',
#  'cef8a667-393e-41a1-beab-cc10cee322f7',
#  '9e5d42d9-65c5-4b6e-a9e1-fe6c98daa473',
#  '9b5375cc-e09a-4f27-9a4c-d07d4eaf6450',
#  '5fcfad22-011d-48c5-ade3-c496173b77e2',
#  'd0a61fc2-b630-4410-89ae-6ca835056bd3',
#  'ad5375f7-a463-4b49-bdb4-55411ccf814c',
#  '604d9032-efe3-4f58-8610-e5b6d6af5a81',
#  '5e379751-4a82-4d10-b8c1-807e3140b376',
#  '62c163ff-0176-4f62-8aa1-3d7c1cb0d7ee',
#  '4a3527b4-d9b3-4feb-84e0-c72f2d87bd30',
#  '513fd221-8562-4e12-850b-6548380547bb',
#  '18921f8c-6bac-434e-9447-04435d449704',
#  '59d704a1-6e84-4ad7-8074-2a072291cca5',
#  '4dd7f0c6-dd13-41c9-aa69-40f208306c8f',
#  '1b502774-f6a5-45e8-8a3e-f5c817e02ae5',
#  'c9d07ffc-d3d2-4583-a20f-fa13a0320ec5',
#  '1f445f41-7cc6-42ea-8964-fdfc7d11f095',
#  '31073f12-a226-464c-a4af-6a791fb5d384',
#  '7693fe99-24c3-4e7d-ad07-724e92bc6b3c',
#  '51fd00a6-1f81-43c3-b764-5a61e8fa20da',
#  '7e5782b7-39cc-402b-8594-98f13888695d',
#  '1a18689e-84a5-40d1-a56a-9ac3fc9e2819',
#  'd8a71265-03de-45c0-bac4-22769e652b47',
#  '67659189-1ea7-4cfb-8fb4-05a1b7cea044',
#  '8ea81ada-b5bb-4878-8a44-4cdf0f093e1c',
#  '84171e6f-0564-4892-97fd-9d5f9c693f37',
#  '8ce4b4ec-adf2-45ce-af56-30bb71f46189',
#  '62575f1e-45f7-4158-bc11-3afc7b1d9646',
#  'fd81d7cf-79ee-4380-a46b-112f9189c7e4',
#  '63a0e60d-5023-450f-8acb-cb0a1d948e2c',
#  'c9d067f5-0ce0-41f4-b5b1-4b204f570419',
#  '3d0f8a25-237f-4516-90df-60ca84b33d3b',
#  '6ed0c065-ccde-4b56-9b5c-917963755d6e',
#  '6899495a-e20c-416d-8eb5-1e12256e6f59',
#  'ef54004d-a905-48a7-9fcd-63dec66337ce',
#  '0d89125c-9693-4bb9-a6af-19b52a959465',
#  '90c4d3fd-c0c9-485a-962b-09ad5a40d7ed',
#  '1bb33c66-2960-4a5b-be8b-d6902dc33158',
#  '731a66a7-5f1e-45f7-8a87-37ab3d7a1d25',
#  '18011c78-1a4e-4fc3-9208-576616293317',
#  '8f7ac19c-ec87-4960-8c66-1dcf0f69c481',
#  'd44d0f0e-3f3f-4fc6-991c-bda0eb601483',
#  'da54a49f-85b8-4d3e-978c-7c491fdd80be',
#  '09e171c9-bc3b-4f18-a529-b4150097c7e2',
#  '86b55761-a05a-43e2-987c-b87f62eb7ba8',
#  '4acd2107-3edd-4304-8444-48e4b303857b',
#  'fb1e53c6-458c-453e-ad0f-006b33dd9072',
#  'b820bfa7-bae4-46b8-a60b-1bf6e63bbacc',
#  'e5ff336a-f850-468e-84a5-d4723502e88a',
#  '0e6c72fc-7f00-4d1c-8b06-c07f398b188e',
#  'f0339137-61bf-4782-8910-e089d5ba2fe1',
#  'f84ffd6c-f5fd-4032-b2d6-466ce27d6f25',
#  '66311397-09af-4283-b2b0-9967165f7891',
#  'ffcc6795-32fb-4564-b800-efd41a4c5c99',
#  '80b4aac9-2c96-4eab-a9b7-763c683ee532',
#  '51a51a40-96bf-4d75-a9ee-3e1a5f2a6922',
#  '243189c6-997f-43b9-a4f4-4f80a37b26c8',
#  'b34db2be-51c5-4a86-a79a-d7506af2444b',
#  '1e8ac950-60e8-4eda-9c65-11ffcc6f35c4',
#  'ca9cd753-731d-43aa-8cd7-304e951e4e82',
#  'e0987ff0-9fc2-4557-9afb-c4389b1a37e3',
#  '36d0a5bf-54cc-4963-a083-6f12cda484fb',
#  '4fee8dd1-35ce-4e11-b450-78d3c676786b',
#  '78b669a3-91ec-4f09-be81-c9639400441b',
#  'c3734416-788c-406b-8977-5d86908e7b6b',
#  '48de42af-2d53-48c3-9b26-3dd1d0f03593',
#  'ede2bc4e-a319-4172-b58d-ce66f62dfaf6',
#  'd8778b0f-887e-4fea-9863-754fc9b65d08',
#  '7b904f1a-fca5-4121-a285-c6e486817ec0',
#  '0ff75cbd-375c-402c-a149-a0f4dea13db2',
#  'b5314654-6319-48ab-a782-544705774747',
#  '5e80c689-0eb7-43ff-a521-41112a0c1601',
#  '9ef17faa-0c19-48c7-a069-d0b8cb38aaa2',
#  '0742af0e-3505-46f5-9d36-a5e878ec6a03',
#  '11159d03-4ff7-4561-9696-9b27070c2175',
#  'fa421c58-0ef3-4ebf-bdc6-4286236c7ece',
#  '15da1ac5-aa17-4238-a832-02f13eb530fd',
#  '4fa8057b-1337-4cd7-a336-ea1c2554cacb',
#  '90474f16-5e77-4428-aea0-265b9d19f23a',
#  '024817c3-d045-493d-bc09-b49b354a8192',
#  '2517228a-2885-463f-9983-97403774c1d4',
#  '375d4a62-30b8-4f03-9007-5a766faa404d',
#  'd8a7fdd6-2d2d-428a-a285-6c3f406fbbeb',
#  '8d21fea8-a10e-4049-aff9-7b41ed77595c',
#  'bbe595ef-e993-4afc-be81-b0efd72c963b',
#  '8e053cda-fdaf-43aa-b580-de37bb954230',
#  '2c78122f-e96e-4909-9904-f92cd2316690',
#  'ec4715f0-6614-4ac0-9d6f-9eb2e5ad453a',
#  '6c949ba4-eca3-4510-ab1c-9dda1bc88a30',
#  '2030cad7-1b4f-4fd7-a6e6-601438c90c6e',
#  'e8ffdbb0-ad56-4de3-8225-a8781883a933',
#  'd6db7a93-de7c-447d-bef1-a916a70db5e7',
#  'eb33909c-59d9-4c6c-8a5a-8f7c52918c37',
#  '88cb3dcd-9744-4ec3-9775-b136073e6442',
#  '84d0ca3c-dbae-4cfd-83d9-9d693b744796',
#  'e3464bdb-d056-4bc2-9b35-1188741dc77b',
#  'c90d3bd9-32cb-483b-ad9d-abf9642fbeb9',
#  'cca57bff-c30f-4f43-980d-d5edbe6869ce',
#  '525c6296-6fc2-4bb1-9152-aac60f866739',
#  '5b2d886f-fcd4-4e03-803b-ebe383af4ef8',
#  'a5a82edf-6226-475f-a1ca-601766c2f673',
#  '6ee16942-6ad9-476b-bb98-ffd685fc2ace',
#  '4395d0cc-8366-4790-aa21-70166137da63',
#  '558d085a-1d03-4f8f-b0e7-5231a94e1bb9',
#  '0bbff6fb-631c-4bc6-a8c3-c692b553b50d',
#  '1ba0a683-5bf2-4547-a326-d63f6e2e1cf3',
#  '8c3e5e20-99e7-4870-b9ae-03080f805573',
#  '09a9f4f4-8b37-4f47-839f-313e0272e63a',
#  '91884ad1-35ed-4dab-b162-f6a99f1de181',
#  'aabdb92d-4e50-4ebe-804d-86dc798c965d',
#  '7247fd8b-b0b4-4662-8018-0cbfadf6c0c1',
#  '783d800f-fc4f-4ec7-aa88-c52cc34c68e0',
#  '9280f771-df41-48d6-8af9-2548e97e8147',
#  '5ef6d826-1d1f-4262-8027-f6e9c49f632c',
#  '82c3ca8e-0a1c-427e-9f90-87141461c84a',
#  '49357e76-0a4a-48a9-85ff-8fce669cf3cb',
#  '333ab765-7e13-49b6-bbc1-8c1bb611462f',
#  '792ade5f-e906-46bc-a055-bed66a053606',
#  'b9100ea3-5db1-47b8-8444-210cd7f05d75',
#  'badd3377-46ac-4ac1-95ca-9d8a16a79f06',
#  'f8d9ef88-10dd-4f07-b9f5-1481e6c232b4',
#  '385165a6-f31a-4aa7-a42e-65247be5569b',
#  '929956be-b47a-495c-a5b2-0716a72d0659',
#  '4a3a02db-23af-4301-b241-85ea5b80a40e',
#  'be4902fe-fa79-443d-8d6c-1c7bcd7bbcc5',
#  '19c1b8ed-2791-4415-982f-694b9efdae0c',
#  '0b0b1aed-77f9-4cd9-9fde-6b21afbe6162',
#  '9baf07c5-e620-4c23-9161-534a5731c94a',
#  '20da189b-96d3-45a5-a7e2-eebe65537ee4',
#  '9d77aeb3-3677-4c69-8ad5-6fed84de44c9',
#  '0f8a1ec6-a76e-4c44-8a68-5f2848072fb2',
#  '3a2012c5-9f64-403b-bf44-7c7c422b3128',
#  '27ff8900-ade2-4fca-920c-677f11627722',
#  '24b99b93-cde6-4c72-a7af-0d62a2885018',
#  '3fc7fb98-fdcd-4654-aa5a-555c51062602',
#  'e7d1d0eb-e398-4b80-bedf-959f56873683',
#  'e5e3fee6-3658-4338-92e6-4c76f242097d',
#  '9cee63e9-8369-407f-a3b9-e6dfea09ae25',
#  '82251a73-3f5f-4647-9cb5-47875ab5d888',
#  '725335dc-4b5d-41ad-a470-0d1ebeb23c0e',
#  '082fe89c-1547-4974-af57-371c1c37b624',
#  '04209a15-1a4c-40c3-8c0f-2c9d8b175521',
#  '452cd479-1577-43f6-bf72-f22c151fb209',
#  'd8ade51c-d8c0-4ab2-af0f-1bf4f80ddab9',
#  '9e00d961-3b60-4ac0-8cfc-37865b6a7926',
#  '679353cb-4256-4d17-b05c-8ff13ca640bf',
#  'f2383e39-e2c8-416d-9939-7f608071ac2c',
#  '1acebde6-29c6-464c-9ef3-5a0ae1e64c02',
#  'c047fdc0-81ab-442f-8d5f-c66ff0f24ed4',
#  '3503c4b0-589c-4ea5-aaf1-45eb393c15e1',
#  '36d05817-f008-4610-9c63-9de0396fdba7',
#  'be4380e5-85f4-4a26-8994-08460bdc1ea8',
#  '2840f9d1-baf4-4f46-8555-96c3e92ff1f7',
#  'ff685c29-62ab-4848-afab-6f17800d1458',
#  'ea06180d-7a0b-42ee-80ad-f186200011dd',
#  'e3969e41-cacf-454c-a9e1-04f954642ec6',
#  '8dfc1449-c847-4bae-b3db-f69a81ba992f',
#  '99f52697-ec4c-4e7d-a9a4-d201e770293a',
#  '3c1aa581-d5d6-49d8-a6e0-50f0deb7e2c7',
#  '024e1930-0d17-4476-9b35-5f8b4615cf71',
#  '23eab442-b0a1-4a97-b831-56f9f9f05ba5',
#  '2be8b8fd-2676-4344-b0a6-cc6b5a144186',
#  '6f8a57a9-355b-4486-a243-28992840c1ec']

# %%
#Prompt template
medical_template = ChatPromptTemplate.from_messages([
    ("system",
     "You are a medical information assistant specializing in TMJ disorders. "
     "Answer ONLY using the provided context. "
     "If the context does not contain enough information, say so clearly. "
     "Use precise medical terminology. "
     "This is for informational purposes only and does not replace professional medical advice."),
    ("human",
     "Context:\n{context}\n\nQuestion:\n{question}\n\nAnswer:")
])

#Build retriever from vector store
retriever = vector_store.as_retriever(
    searchType="mmr",
    searchKwargs={"k": 5}
)


#Function to format docs and create RunnableLambda
def format_docs(docs):
    formatted = "\n\n".join(doc.page_content for doc in docs)
    print(formatted)
    return formatted

format_docs_runnable = RunnableLambda(format_docs)

output_parser = StrOutputParser()

# %%
#Initialize LLM
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature = 0.0
)

# %%
#Create RAG chain
rag_chain = (
    {
        "context": retriever | format_docs_runnable,
        "question": RunnablePassthrough(),
    }
    | medical_template
    | llm
    | output_parser  
)

# %%
#Query the chain
answer = rag_chain.invoke("What should I know about TMJ disorders?")
print(answer)
# Out:
# TMJ disorders [https://medlineplus.gov/ency/article/001227 htm]
#
# TMJ disorders are not uncommon and have a variety of symptoms. Patients may complain of earaches, headaches and limited ability to open their mouth. They may also complain of clicking or grating sounds in the joint and feel pain when opening and closing their mouth.
#
# e TMJ Disorders [https://www.mayoclinic.org/diseases-conditions/tmj/symptoms-causes/syc-20350941 ?p=1] (Mayo Foundation for Medical Education and Research)
#
# Temporomandibular disorders, commonly called “TMD,” are a group of painful conditions that affect the jaw joint and the muscles that control jaw movement. “TMD” refers to the disorders, and “TMJ” refers to the temporomandibular joint itself. People have two TMJs; one on each side of the jaw. Injury to the jaw can sometimes lead to TMDs, but in most cases the cause is not clear. Recent research suggests a combination of genes, psychological and life stressors, and how someone perceives pain may play a part in why a TMD starts and whether it will be long-lasting.
# TMJ disorders, also known as temporomandibular disorders (TMD), are a group of painful conditions affecting the temporomandibular joint (TMJ) and the associated muscles responsible for jaw movement. Common symptoms include:
#
# - Earaches
# - Headaches
# - Limited ability to open the mouth
# - Clicking or grating sounds in the joint
# - Pain during mouth opening and closing
#
# The etiology of TMD is often unclear, but it may involve a combination of genetic factors, psychological influences, life stressors, and individual pain perception. While jaw injury can contribute to the development of TMD, many cases arise without a specific identifiable cause.
#
# It is important to consult a healthcare professional for a proper diagnosis and management plan if you experience symptoms associated with TMJ disorders.
