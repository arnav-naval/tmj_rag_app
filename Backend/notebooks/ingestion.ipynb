# %%
from unstructured.partition.pdf import partition_pdf
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_chroma import Chroma
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

file_path = "C:/Users/User/Downloads/tmj_rag_app/Backend/data/pdfs"
base_file_name = "tmjDoc2"

# %%
#Import env variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Partition the PDF file
elements = partition_pdf(
    filename=f"{file_path}/{base_file_name}.pdf",
    strategy="auto",
    infer_table_structure=True
)
# Out:
# Warning: No languages specified, defaulting to English.

# %%
# Display the elements partitioned from the PDF file
for i, element in enumerate(elements):
    print(f"\n--- Element {i} ---")
    print(f"Type: {element.category}")
    print(f"Text: {element.text}")
    print(f"Metadata: {element.metadata}")
# Out:
# --- Element 0 ---
# Type: Header
# Text: 12/5/25, 3:44 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026584B82030>
#
# --- Element 1 ---
# Type: Header
# Text: TMD and Jaw Pain | NIDCR
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872D7500>
#
# --- Element 2 ---
# Type: NarrativeText
# Text: = An official website of the United States government Here’s how you know
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026584B80980>
#
# --- Element 3 ---
# Type: Image
# Text:
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026584B80B00>
#
# --- Element 4 ---
# Type: Title
# Text: National Institute of Dental and Craniofacial Research
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026584B81370>
#
# --- Element 5 ---
# Type: NarrativeText
# Text: </>
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026584B80E90>
#
# --- Element 6 ---
# Type: NarrativeText
# Text: MENU
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872F8F50>
#
# --- Element 7 ---
# Type: UncategorizedText
# Text: Search
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587613110>
#
# --- Element 8 ---
# Type: UncategorizedText
# Text: [Q]
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587610410>
#
# --- Element 9 ---
# Type: Title
# Text: Temporomandibular Disorders and Jaw Pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872F9760>
#
# --- Element 10 ---
# Type: Title
# Text: f xX in @
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587613CE0>
#
# --- Element 11 ---
# Type: NarrativeText
# Text: The most common cause of jaw pain is a group of conditions called temporomandibular disorders (TMDs). These disorders can lead to ongoing or repeated pain and difficulty moving the jaw, affecting the joint, nearby muscles, and supporting tissues. In addition, TMDs can occur alone, or with other medical conditions such as migraines, back pain, sleep problems, fibromyalgia, arthritis, and irritable bowel syndrome. While research on TMDs is ongoing, larger nationwide longitudinal studies are needed to better understand TMDs and how they affect people.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587610140>
#
# --- Element 12 ---
# Type: Title
# Text: Prevalence of TMD and Jaw Pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587613470>
#
# --- Element 13 ---
# Type: NarrativeText
# Text: TMDs are the second most commonly occurring musculoskeletal condition resulting in pain and disability (after chronic low back pain). TMD affects about 5% of adults in the U.S., but .«s number can vary depending on who is studied and how ~ wes so
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587611E20>
#
# --- Element 14 ---
# Type: UncategorizedText
# Text: measured. TMD can be a temporary problem that goes _—_ Was this page helpful?
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265876113D0>
#
# --- Element 15 ---
# Type: UncategorizedText
# Text: lasting (chronic) condition. Unusual for chronic pain co
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587610740>
#
# --- Element 16 ---
# Type: UncategorizedText
# Text: higher among young persons between the ages of 20 ar
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC31850>
#
# --- Element 17 ---
# Type: UncategorizedText
# Text: common in women than men.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC33410>
#
# --- Element 18 ---
# Type: Image
# Text: (0 Yes ( O No
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587613140>
#
# --- Element 19 ---
# Type: NarrativeText
# Text: € Powered by Crazy Egg
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587612810>
#
# --- Element 20 ---
# Type: UncategorizedText
# Text: https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC31640>
#
# --- Element 21 ---
# Type: Header
# Text: 1/19
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265876125A0>
#
# --- Element 22 ---
# Type: Header
# Text: 12/5/25, 3:44 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872F9340>
#
# --- Element 23 ---
# Type: Header
# Text: TMD and Jaw Pain | NIDCR
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026584B82DB0>
#
# --- Element 24 ---
# Type: NarrativeText
# Text: Assessing TMDs in a research setting is complex. TMDs are often measured by asking people about symptoms such as muscle, joint, facial or jaw pain, difficulty chewing, and joint sounds. However, variation in the assessment and reporting of TMDs makes it difficult to determine its precise prevalence.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587610BC0>
#
# --- Element 25 ---
# Type: Title
# Text: Table 1: Prevalence of Jaw Pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587611EB0>
#
# --- Element 26 ---
# Type: NarrativeText
# Text: Table 1 presents results from U.S. studies reporting the prevalence of jaw pain along with the methods of measurement.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265876126C0>
#
# --- Element 27 ---
# Type: Table
# Text: Source Pub. Study Stud ucy Measure Year Population Design Lipton et al (1), National Health Interview Survey <https://pubmed.ncbi.nlm.nih.gov/8409001/> 1993 U.S adult civilians Cross-sectional national household interview survey (self-reported questionnaires) (n=42,370) "During the past 6 months, pain in the jaw joint or in front of the ear" more than once. 6-month prevalence All: 5.3% Men: 3.5% Women: 6.9% Prevalance of Jaw Pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587610470>
#
# --- Element 28 ---
# Type: UncategorizedText
# Text: Was this page helpful?
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC33890>
#
# --- Element 29 ---
# Type: Image
# Text: € Powered by Crazy Egg
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265876101A0>
#
# --- Element 30 ---
# Type: UncategorizedText
# Text: https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC31E50>
#
# --- Element 31 ---
# Type: Header
# Text: 2/9
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587301DF0>
#
# --- Element 32 ---
# Type: Header
# Text: 12/5/25, 3:44 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC32DB0>
#
# --- Element 33 ---
# Type: Header
# Text: TMD and Jaw Pain | NIDCR
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265876117C0>
#
# --- Element 34 ---
# Type: UncategorizedText
# Text: Source
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E7200>
#
# --- Element 35 ---
# Type: UncategorizedText
# Text: Pub. Study ; Study Measure oflew Year Population Design Pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E6EA0>
#
# --- Element 36 ---
# Type: Title
# Text: Plesh et al (2), U.S. National Health
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026584B82960>
#
# --- Element 37 ---
# Type: Title
# Text: Interview Survey
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA9B50>
#
# --- Element 38 ---
# Type: NarrativeText
# Text: <https://pubmed.ncbi.nlm.nih.gov/21359234/>
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA8560>
#
# --- Element 39 ---
# Type: UncategorizedText
# Text: 2011
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC43920>
#
# --- Element 40 ---
# Type: UncategorizedText
# Text: U.S. adult civilians
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC41F70>
#
# --- Element 41 ---
# Type: UncategorizedText
# Text: Cross-sectional national household
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC42420>
#
# --- Element 42 ---
# Type: UncategorizedText
# Text: interview survey (self-reported questionnaires) (n=189,992)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC439E0>
#
# --- Element 43 ---
# Type: NarrativeText
# Text: "During the past three months, did you
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA8140>
#
# --- Element 44 ---
# Type: NarrativeText
# Text: have... “facial ache or pain in the jaw
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DAA5A0>
#
# --- Element 45 ---
# Type: NarrativeText
# Text: muscles or the joint in front of the ear?”
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA9BE0>
#
# --- Element 46 ---
# Type: NarrativeText
# Text: 3-month prevalence
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA9AC0>
#
# --- Element 47 ---
# Type: NarrativeText
# Text: All: 4.6%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DAA4B0>
#
# --- Element 48 ---
# Type: NarrativeText
# Text: Men: 2.9%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA95E0>
#
# --- Element 49 ---
# Type: NarrativeText
# Text: Women: 6.1%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA9880>
#
# --- Element 50 ---
# Type: Title
# Text: Alkhubaizi et al (3), Osteoarthritis
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA9250>
#
# --- Element 51 ---
# Type: Title
# Text: Initiative: A Knee Health study
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587617E60>
#
# --- Element 52 ---
# Type: NarrativeText
# Text: <https://pubmed.ncbi.nlm.nih.gov/30211397/>
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587617200>
#
# --- Element 53 ---
# Type: NarrativeText
# Text: 2018
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587616E70>
#
# --- Element 54 ---
# Type: NarrativeText
# Text: Subjects with a history of knee pain, age
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587617EF0>
#
# --- Element 55 ---
# Type: NarrativeText
# Text: 45 to 79 years
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587616CC0>
#
# --- Element 56 ---
# Type: NarrativeText
# Text: U.S. national prospective cohort study
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587616DB0>
#
# --- Element 57 ---
# Type: NarrativeText
# Text: (self-reported facial pain questionnaire)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E7230>
#
# --- Element 58 ---
# Type: UncategorizedText
# Text: (n=4,423)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC43E30>
#
# --- Element 59 ---
# Type: NarrativeText
# Text: "Jaw joint or in front of ear, pain or aching, past 30 days"
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E7020>
#
# --- Element 60 ---
# Type: UncategorizedText
# Text: "Jaw joint or in front of ear, how many days had pain or aching, past 30 days" ¥ ; P &P ¥ Baseline prevalence
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC40950>
#
# --- Element 61 ---
# Type: UncategorizedText
# Text: Was this page helpful?
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC42B40>
#
# --- Element 62 ---
# Type: NarrativeText
# Text: Overall: 9.3%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E7380>
#
# --- Element 63 ---
# Type: UncategorizedText
# Text: Women had a 2.4% higher prevalence rate
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC421E0>
#
# --- Element 64 ---
# Type: UncategorizedText
# Text: of facial pain compared to men
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC41160>
#
# --- Element 65 ---
# Type: Image
# Text: a > % yy / = € Powered by Crazy Egg
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E7D70>
#
# --- Element 66 ---
# Type: UncategorizedText
# Text: https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC42840>
#
# --- Element 67 ---
# Type: Header
# Text: 3/9
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E7770>
#
# --- Element 68 ---
# Type: Header
# Text: 12/5/25, 3:44 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DAAD50>
#
# --- Element 69 ---
# Type: Header
# Text: TMD and Jaw Pain | NIDCR
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA8E90>
#
# --- Element 70 ---
# Type: UncategorizedText
# Text: Source
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC416D0>
#
# --- Element 71 ---
# Type: UncategorizedText
# Text: Pub. Study . Study Measure oflew Year Population Design Pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC40B00>
#
# --- Element 72 ---
# Type: Title
# Text: Yost et al (4), Orofacial Pain:
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DA8260>
#
# --- Element 73 ---
# Type: Title
# Text: Prospective Evaluation and Risk
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587616F90>
#
# --- Element 74 ---
# Type: Title
# Text: Assessment study
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587616840>
#
# --- Element 75 ---
# Type: NarrativeText
# Text: <https://www.ncbi.nlm.nih.gov/books/nbk557996/>
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E7B30>
#
# --- Element 76 ---
# Type: Title
# Text: 2020
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E7F20>
#
# --- Element 77 ---
# Type: NarrativeText
# Text: U.S. civilians, age 18 to 44
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E7CE0>
#
# --- Element 78 ---
# Type: UncategorizedText
# Text: Cross-sectional study nested within the
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC400B0>
#
# --- Element 79 ---
# Type: UncategorizedText
# Text: parent Orofacial Pain: Prospective
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC40C80>
#
# --- Element 80 ---
# Type: NarrativeText
# Text: Evaluation and Risk Assessment Study
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872FA450>
#
# --- Element 81 ---
# Type: NarrativeText
# Text: (telephone interview, clinical exam, and
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587612780>
#
# --- Element 82 ---
# Type: NarrativeText
# Text: pain test)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC42900>
#
# --- Element 83 ---
# Type: UncategorizedText
# Text: (n=846)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC430E0>
#
# --- Element 84 ---
# Type: UncategorizedText
# Text: High-impact orofacial pain (pain in the
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265879431D0>
#
# --- Element 85 ---
# Type: NarrativeText
# Text: cheeks, jaw muscles, and/or jaw joints)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC434D0>
#
# --- Element 86 ---
# Type: NarrativeText
# Text: experienced for at least 6 months
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC435F0>
#
# --- Element 87 ---
# Type: NarrativeText
# Text: 6-month prevalence
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC41FD0>
#
# --- Element 88 ---
# Type: NarrativeText
# Text: All TMD cases: 33.5%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC40920>
#
# --- Element 89 ---
# Type: NarrativeText
# Text: Men: 35.1%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC40650>
#
# --- Element 90 ---
# Type: NarrativeText
# Text: Women: 33.0%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC404A0>
#
# --- Element 91 ---
# Type: NarrativeText
# Text: Combined:
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC43470>
#
# --- Element 92 ---
# Type: NarrativeText
# Text: 18-24: 27.1%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC43B60>
#
# --- Element 93 ---
# Type: NarrativeText
# Text: 25-34: 32.8%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC40200>
#
# --- Element 94 ---
# Type: NarrativeText
# Text: 35-44: 43.2%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC41BB0>
#
# --- Element 95 ---
# Type: UncategorizedText
# Text: Was this page helpful?
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587941E20>
#
# --- Element 96 ---
# Type: Image
# Text: € Powered by Crazy Egg
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC42F30>
#
# --- Element 97 ---
# Type: UncategorizedText
# Text: https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587941F70>
#
# --- Element 98 ---
# Type: Header
# Text: Al9
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC41730>
#
# --- Element 99 ---
# Type: Header
# Text: 12/5/25, 3:44 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E5880>
#
# --- Element 100 ---
# Type: Header
# Text: TMD and Jaw Pain | NIDCR
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587616780>
#
# --- Element 101 ---
# Type: Table
# Text: Pub. Study Study Prevalance Source . . Measure of Jaw Year Population Design Pain Yost et al (5), National Health Interview Survey <https://www.ncbi.nlm.nih.gov/books/nbk558001/> 2020 U.S. adults, age 18 to 74 Cross-sectional national household interview survey (face-to-face, computer- assisted personal interviews) (n=52,159) Jaw or face pain that lasted 21 day in the past 3 months 3-month prevalence All: 4.8% Men: 3.2% Women: 6.2% Combined: 18-24: 4.2% 25-34: 4.9% 35-44: 5.2% 45-54: 5.4% 55-64: 5.1% 65-74: 3.7%
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587612270>
#
# --- Element 102 ---
# Type: Title
# Text: Treatment Needs and Financial Costs Associated with TMDs
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC40380>
#
# --- Element 103 ---
# Type: NarrativeText
# Text: Treating TMDs can be costly, and the condition often affects a person’s daily comfort and quality of life. There is no single treatment for TMDs as it can have many different causes and symptoms. Treatments need to match the individual patient’s needs. Treatment options re’ ~¢ from simple approaches such as self-care, pain medication, and physical therapy, to more serious treatments like surgery. Further advances in TM i
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC41370>
#
# --- Element 104 ---
# Type: UncategorizedText
# Text: 2 to enhance the quality of care for individuals with TMDs Was this page helpful?
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC41220>
#
# --- Element 105 ---
# Type: NarrativeText
# Text: Earlier studies suggest that people with TMDs have dou those without it. A small proportion of individuals with portion of the total health care costs associated withth needed to better understand current health care practi: . i coverage, and the long-term needs of people living with
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC43710>
#
# --- Element 106 ---
# Type: UncategorizedText
# Text: \
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC43830>
#
# --- Element 107 ---
# Type: UncategorizedText
# Text: Me
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC32F00>
#
# --- Element 108 ---
# Type: UncategorizedText
# Text: € Powered by Crazy Egg
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942FF0>
#
# --- Element 109 ---
# Type: UncategorizedText
# Text: ....--.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942330>
#
# --- Element 110 ---
# Type: NarrativeText
# Text: https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC41970>
#
# --- Element 111 ---
# Type: UncategorizedText
# Text: >
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265879408C0>
#
# --- Element 112 ---
# Type: Header
# Text: 5/9
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC41310>
#
# --- Element 113 ---
# Type: Header
# Text: 12/5/25, 3:44 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC42D20>
#
# --- Element 114 ---
# Type: Header
# Text: TMD and Jaw Pain | NIDCR
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC42690>
#
# --- Element 115 ---
# Type: Title
# Text: Table 2: Financial Costs Associated with TMD in the U.S.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872C1E20>
#
# --- Element 116 ---
# Type: NarrativeText
# Text: Table 2 presents results from U.S.-based studies that examined TMD treatment costs.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DAB140>
#
# --- Element 117 ---
# Type: Table
# Text: Pub. Study Source . Year Population Shimshak and DeFuria (6) 1998 Patientsin <https://pubmed.ncbi.nlm.nih.gov/9852811/> aclaims database of a large New England managed care organization Stud “y Measure Results Design Cross- Overall Patients with sectional 1994 health TMD used study of care costs more health claims data ofTMDvs. — careservices from one nonTMD and had year (1994) patients higher (n=1,713 associated cases and costs than 532,485 patients unmatched without a TMD controls) claim TMD patients / non-TMD patients All inpatient claims (per 1,000 admissions): 107.4 / 80.7 All costs per patient: $936 / $517 All inpatient claims excluding TMD cla (per 1.000
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943800>
#
# --- Element 118 ---
# Type: UncategorizedText
# Text: Was this page helpful?
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587941310>
#
# --- Element 119 ---
# Type: Image
# Text: ( : »\ Yes ) a y, f \ { No € Powered by Crazy Egg
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943E90>
#
# --- Element 120 ---
# Type: UncategorizedText
# Text: https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943BF0>
#
# --- Element 121 ---
# Type: Header
# Text: 6/9
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943BC0>
#
# --- Element 122 ---
# Type: Header
# Text: 12/5/25, 3:44 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC42570>
#
# --- Element 123 ---
# Type: Header
# Text: TMD and Jaw Pain | NIDCR
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587611490>
#
# --- Element 124 ---
# Type: Table
# Text: Source Pub, — Study . Study Measure Results Year Population Design White et al (7) 2001 TMD Matched Compared TMD cases <https://pubmed.ncbi.nlm.nih.gov/11443827/> patients and case- the useand overall used matched control cost of significantly controls study medical more health enrolledina (n=8,801 anddental services and largehealth casesand = care had 1.6 times maintenance 8,801 services for higher costs organization matched TMD for all services controls) patients than controls and Female TMD matched cases had controls higher costs than the male TMD cases Cases / Controls Mean TMD clinic visits: 3.26 / N/A Mean dental visits: 7.46 / 5.28 Mean pharmacy dispensings: 61.69 / 35.91 Mean outpatient visits: 4. /
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942A80>
#
# --- Element 125 ---
# Type: UncategorizedText
# Text: 24.94
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587940200>
#
# --- Element 126 ---
# Type: UncategorizedText
# Text: Was this page helpful?
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943B90>
#
# --- Element 127 ---
# Type: Image
# Text: € Powered by Crazy Egg
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587940140>
#
# --- Element 128 ---
# Type: UncategorizedText
# Text: https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943110>
#
# --- Element 129 ---
# Type: Header
# Text: 719
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942360>
#
# --- Element 130 ---
# Type: Header
# Text: 12/5/25, 3:44 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587941940>
#
# --- Element 131 ---
# Type: Header
# Text: TMD and Jaw Pain | NIDCR
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265872E4FB0>
#
# --- Element 132 ---
# Type: Table
# Text: Pub. Study Study . . Measure Results Year Population Design Source Mean outside claim/referral Inpatient: 0.09 / 0.08 Outpatient: 2.66 / 2.14
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587941D00>
#
# --- Element 133 ---
# Type: Title
# Text: Related Links
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942600>
#
# --- Element 134 ---
# Type: ListItem
# Text: Health Info: Temporomandibular Disorders <https://www.nidcr.nih.gov/health-info/tmd>
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587941B50>
#
# --- Element 135 ---
# Type: UncategorizedText
# Text: ¢
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943C20>
#
# --- Element 136 ---
# Type: ListItem
# Text: e Learn more about TMD research supported by NIDCR: Research Investments and Advances <https://www.nidcr.nih.gov/grants-funding/funded-research/research-investments-
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942B10>
#
# --- Element 137 ---
# Type: NarrativeText
# Text: advances/temporomandibular-disorders>
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942C00>
#
# --- Element 138 ---
# Type: Title
# Text: References
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942270>
#
# --- Element 139 ---
# Type: ListItem
# Text: 1. Lipton JA, Ship JA, Larach-Robinson D. Estimated prevalence and distribution of reported orofacial pain in the United States <https://pubmed.ncbi.nlm.nih.gov/8409001/>. J Am Dent Assoc. 1993 Oct;124(10):115-21. doi: 10.14219/jada.archive.1993.0200.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943CE0>
#
# --- Element 140 ---
# Type: ListItem
# Text: 2. Plesh O, Adams SH, Gansky SA. Racial/ethnic and gender prevalences in reported common pains in a national sample <https://pubmed.ncbi.nlm.nih.gov/21359234/>. J Orofac Pain. 2011 Winter;25(1):25-31.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943380>
#
# --- Element 141 ---
# Type: ListItem
# Text: 3. Alkhubaizi Q, Sorkin JD, Hochberg MC, Gordon SM. Risk factors for facial pain: Data from the Osteoarthritis Initiative Study <https://pubmed.ncbi.nlm.nih.gov/30211397/>. J Dent Oral Biol. 2017;2(3):1033. Epub 2017 Feb 9.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265879407D0>
#
# --- Element 142 ---
# Type: ListItem
# Text: 4. National Academies of Sciences, Engineering, and Medicine; Health and Medicine Division; Board on Health Care Services; Board on Health Sciences Policy; Committee on Temporomandibular Disorders (TMDs): From Research Discoveries to Clinical Treatment. Appendix C, Prevalence, impact, and costs of treatment for temporomandibular disorders <https://www.ncbi.nlm.nih.gov/books/nbk557996/>. In: Yost O, Liverman CT, English R, editors. Temporomandibular disorders: Priorities for research and care. Washington (DC): National Academies Press (US); 2020 Mar 12.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587941640>
#
# --- Element 143 ---
# Type: ListItem
# Text: 5. National Academies of Sciences, Engineering, and Medicine; Health and Medicine Division; Board on Heaun Care Services; Board on Health Sciences Policy; Committee on
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943AD0>
#
# --- Element 144 ---
# Type: UncategorizedText
# Text: Research Discoveries to Clinical Treatment. Chapter 3, Individ' Was this page helpful?
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587603C80>
#
# --- Element 145 ---
# Type: UncategorizedText
# Text: <https://www.ncbi.nlm.nih.gov/books/nbk558001/>. In: Yost O, Liverm
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587601BE0>
#
# --- Element 146 ---
# Type: UncategorizedText
# Text: disorders: Priorities for research and care. Washington (DC): Na
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587603770>
#
# --- Element 147 ---
# Type: ListItem
# Text: 6. Shimshak DG, DeFuria, MC. Health care utilization by patients <https://pubmed.ncbi.nlm.nih.gov/9852811/>. Cranio.1998 Jul;16(3):)
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942990>
#
# --- Element 148 ---
# Type: ListItem
# Text: 7. White BA, Williams LA, Leben JR. Health care utilization cost a! members with temporomandibular disorders <https://pubmed.n Spring;15(2):158-169.
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942510>
#
# --- Element 149 ---
# Type: Image
# Text: ( Yes ) > < | No ) \ )
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587941610>
#
# --- Element 150 ---
# Type: UncategorizedText
# Text: € Powered by Crazy Egg
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587601C10>
#
# --- Element 151 ---
# Type: UncategorizedText
# Text: https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587603620>
#
# --- Element 152 ---
# Type: Header
# Text: 8/9
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943320>
#
# --- Element 153 ---
# Type: Header
# Text: 12/5/25, 3:44 PM
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x00000265879403B0>
#
# --- Element 154 ---
# Type: Header
# Text: TMD and Jaw Pain | NIDCR
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943F20>
#
# --- Element 155 ---
# Type: UncategorizedText
# Text: Last Reviewed
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x000002658FC40B30>
#
# --- Element 156 ---
# Type: UncategorizedText
# Text: August 2025
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026583DAA8D0>
#
# --- Element 157 ---
# Type: Table
# Text: Home<j Web Policies </about-us/web-policies> Privacy </about-us/privacy-policy> Contact Us </about-us/contact-nider> Freedom of Information Act No Fear Act </about-us/freedom-information-act- <https://www.edi.nih.gov/no-fear-act> requests> Office of Inspector General HHS Vulnerability Disclosure Employee Intranet - Staff Only <https://oig.hhs.gov/> <https://www.hhs.gov/vulnerability- <https://nih.sharepoint.com/sites/nidcr- disclosure-policy/index.html> intranet>
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943B60>
#
# --- Element 158 ---
# Type: UncategorizedText
# Text: Hector
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587600D40>
#
# --- Element 159 ---
# Type: UncategorizedText
# Text: Semin: lL
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587603260>
#
# --- Element 160 ---
# Type: UncategorizedText
# Text: Was this page helpful?
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587602930>
#
# --- Element 161 ---
# Type: Image
# Text: € Powered by Crazy Egg
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587942C60>
#
# --- Element 162 ---
# Type: UncategorizedText
# Text: https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587600740>
#
# --- Element 163 ---
# Type: Header
# Text: 9/9
# Metadata: <unstructured.documents.elements.ElementMetadata object at 0x0000026587943080>

# %%
# Convert to LangChain Documents
docs = []
MIN_CHAR_LENGTH = 50

for el in elements:
    #Skip headers, dont contain useful info
    if el.category == "Header":
        continue
    
    text = getattr(el, "text", None)
    if not text:
        continue

    if (len(text.strip()) < MIN_CHAR_LENGTH):
        continue

    meta = el.to_dict().get("metadata", {}) or {}
    docs.append(
        Document(
            page_content=text,
            metadata={
                "source": base_file_name,
                "page_number": meta.get("page_number"),
                "type": el.category if hasattr(el, "category") else meta.get("type"),
            },
        )
    )

#Print documents
for i, doc in enumerate(docs, 1):
    meta = doc.metadata
    print(f"--- Document {i} ---")
    print(f"Source: {meta.get('source')} | Page: {meta.get('page_number')} | Type: {meta.get('type')}")
    print(f"Content length: {len(doc.page_content)} characters")
    print(f"Content:\n{doc.page_content}")
    print()

splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000, 
    chunk_overlap=200,
    add_start_index=True
)
chunked_docs = splitter.split_documents(docs)
# Out:
# --- Document 1 ---
# Source: tmjDoc2 | Page: 1 | Type: NarrativeText
# Content length: 73 characters
# Content:
# = An official website of the United States government Here’s how you know
#
# --- Document 2 ---
# Source: tmjDoc2 | Page: 1 | Type: Title
# Content length: 54 characters
# Content:
# National Institute of Dental and Craniofacial Research
#
# --- Document 3 ---
# Source: tmjDoc2 | Page: 1 | Type: NarrativeText
# Content length: 554 characters
# Content:
# The most common cause of jaw pain is a group of conditions called temporomandibular disorders (TMDs). These disorders can lead to ongoing or repeated pain and difficulty moving the jaw, affecting the joint, nearby muscles, and supporting tissues. In addition, TMDs can occur alone, or with other medical conditions such as migraines, back pain, sleep problems, fibromyalgia, arthritis, and irritable bowel syndrome. While research on TMDs is ongoing, larger nationwide longitudinal studies are needed to better understand TMDs and how they affect people.
#
# --- Document 4 ---
# Source: tmjDoc2 | Page: 1 | Type: NarrativeText
# Content length: 246 characters
# Content:
# TMDs are the second most commonly occurring musculoskeletal condition resulting in pain and disability (after chronic low back pain). TMD affects about 5% of adults in the U.S., but .«s number can vary depending on who is studied and how ~ wes so
#
# --- Document 5 ---
# Source: tmjDoc2 | Page: 1 | Type: UncategorizedText
# Content length: 77 characters
# Content:
# measured. TMD can be a temporary problem that goes _—_ Was this page helpful?
#
# --- Document 6 ---
# Source: tmjDoc2 | Page: 1 | Type: UncategorizedText
# Content length: 56 characters
# Content:
# lasting (chronic) condition. Unusual for chronic pain co
#
# --- Document 7 ---
# Source: tmjDoc2 | Page: 1 | Type: UncategorizedText
# Content length: 52 characters
# Content:
# higher among young persons between the ages of 20 ar
#
# --- Document 8 ---
# Source: tmjDoc2 | Page: 1 | Type: UncategorizedText
# Content length: 87 characters
# Content:
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Document 9 ---
# Source: tmjDoc2 | Page: 2 | Type: NarrativeText
# Content length: 300 characters
# Content:
# Assessing TMDs in a research setting is complex. TMDs are often measured by asking people about symptoms such as muscle, joint, facial or jaw pain, difficulty chewing, and joint sounds. However, variation in the assessment and reporting of TMDs makes it difficult to determine its precise prevalence.
#
# --- Document 10 ---
# Source: tmjDoc2 | Page: 2 | Type: NarrativeText
# Content length: 118 characters
# Content:
# Table 1 presents results from U.S. studies reporting the prevalence of jaw pain along with the methods of measurement.
#
# --- Document 11 ---
# Source: tmjDoc2 | Page: 2 | Type: Table
# Content length: 433 characters
# Content:
# Source Pub. Study Stud ucy Measure Year Population Design Lipton et al (1), National Health Interview Survey <https://pubmed.ncbi.nlm.nih.gov/8409001/> 1993 U.S adult civilians Cross-sectional national household interview survey (self-reported questionnaires) (n=42,370) "During the past 6 months, pain in the jaw joint or in front of the ear" more than once. 6-month prevalence All: 5.3% Men: 3.5% Women: 6.9% Prevalance of Jaw Pain
#
# --- Document 12 ---
# Source: tmjDoc2 | Page: 2 | Type: UncategorizedText
# Content length: 87 characters
# Content:
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Document 13 ---
# Source: tmjDoc2 | Page: 3 | Type: UncategorizedText
# Content length: 60 characters
# Content:
# Pub. Study ; Study Measure oflew Year Population Design Pain
#
# --- Document 14 ---
# Source: tmjDoc2 | Page: 3 | Type: UncategorizedText
# Content length: 59 characters
# Content:
# interview survey (self-reported questionnaires) (n=189,992)
#
# --- Document 15 ---
# Source: tmjDoc2 | Page: 3 | Type: NarrativeText
# Content length: 60 characters
# Content:
# "Jaw joint or in front of ear, pain or aching, past 30 days"
#
# --- Document 16 ---
# Source: tmjDoc2 | Page: 3 | Type: UncategorizedText
# Content length: 109 characters
# Content:
# "Jaw joint or in front of ear, how many days had pain or aching, past 30 days" ¥ ; P &P ¥ Baseline prevalence
#
# --- Document 17 ---
# Source: tmjDoc2 | Page: 3 | Type: UncategorizedText
# Content length: 87 characters
# Content:
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Document 18 ---
# Source: tmjDoc2 | Page: 4 | Type: UncategorizedText
# Content length: 60 characters
# Content:
# Pub. Study . Study Measure oflew Year Population Design Pain
#
# --- Document 19 ---
# Source: tmjDoc2 | Page: 4 | Type: UncategorizedText
# Content length: 87 characters
# Content:
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Document 20 ---
# Source: tmjDoc2 | Page: 5 | Type: Table
# Content length: 517 characters
# Content:
# Pub. Study Study Prevalance Source . . Measure of Jaw Year Population Design Pain Yost et al (5), National Health Interview Survey <https://www.ncbi.nlm.nih.gov/books/nbk558001/> 2020 U.S. adults, age 18 to 74 Cross-sectional national household interview survey (face-to-face, computer- assisted personal interviews) (n=52,159) Jaw or face pain that lasted 21 day in the past 3 months 3-month prevalence All: 4.8% Men: 3.2% Women: 6.2% Combined: 18-24: 4.2% 25-34: 4.9% 35-44: 5.2% 45-54: 5.4% 55-64: 5.1% 65-74: 3.7%
#
# --- Document 21 ---
# Source: tmjDoc2 | Page: 5 | Type: Title
# Content length: 56 characters
# Content:
# Treatment Needs and Financial Costs Associated with TMDs
#
# --- Document 22 ---
# Source: tmjDoc2 | Page: 5 | Type: NarrativeText
# Content length: 424 characters
# Content:
# Treating TMDs can be costly, and the condition often affects a person’s daily comfort and quality of life. There is no single treatment for TMDs as it can have many different causes and symptoms. Treatments need to match the individual patient’s needs. Treatment options re’ ~¢ from simple approaches such as self-care, pain medication, and physical therapy, to more serious treatments like surgery. Further advances in TM i
#
# --- Document 23 ---
# Source: tmjDoc2 | Page: 5 | Type: UncategorizedText
# Content length: 81 characters
# Content:
# 2 to enhance the quality of care for individuals with TMDs Was this page helpful?
#
# --- Document 24 ---
# Source: tmjDoc2 | Page: 5 | Type: NarrativeText
# Content length: 284 characters
# Content:
# Earlier studies suggest that people with TMDs have dou those without it. A small proportion of individuals with portion of the total health care costs associated withth needed to better understand current health care practi: . i coverage, and the long-term needs of people living with
#
# --- Document 25 ---
# Source: tmjDoc2 | Page: 5 | Type: NarrativeText
# Content length: 87 characters
# Content:
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Document 26 ---
# Source: tmjDoc2 | Page: 6 | Type: Title
# Content length: 56 characters
# Content:
# Table 2: Financial Costs Associated with TMD in the U.S.
#
# --- Document 27 ---
# Source: tmjDoc2 | Page: 6 | Type: NarrativeText
# Content length: 83 characters
# Content:
# Table 2 presents results from U.S.-based studies that examined TMD treatment costs.
#
# --- Document 28 ---
# Source: tmjDoc2 | Page: 6 | Type: Table
# Content length: 669 characters
# Content:
# Pub. Study Source . Year Population Shimshak and DeFuria (6) 1998 Patientsin <https://pubmed.ncbi.nlm.nih.gov/9852811/> aclaims database of a large New England managed care organization Stud “y Measure Results Design Cross- Overall Patients with sectional 1994 health TMD used study of care costs more health claims data ofTMDvs. — careservices from one nonTMD and had year (1994) patients higher (n=1,713 associated cases and costs than 532,485 patients unmatched without a TMD controls) claim TMD patients / non-TMD patients All inpatient claims (per 1,000 admissions): 107.4 / 80.7 All costs per patient: $936 / $517 All inpatient claims excluding TMD cla (per 1.000
#
# --- Document 29 ---
# Source: tmjDoc2 | Page: 6 | Type: UncategorizedText
# Content length: 87 characters
# Content:
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Document 30 ---
# Source: tmjDoc2 | Page: 7 | Type: Table
# Content length: 716 characters
# Content:
# Source Pub, — Study . Study Measure Results Year Population Design White et al (7) 2001 TMD Matched Compared TMD cases <https://pubmed.ncbi.nlm.nih.gov/11443827/> patients and case- the useand overall used matched control cost of significantly controls study medical more health enrolledina (n=8,801 anddental services and largehealth casesand = care had 1.6 times maintenance 8,801 services for higher costs organization matched TMD for all services controls) patients than controls and Female TMD matched cases had controls higher costs than the male TMD cases Cases / Controls Mean TMD clinic visits: 3.26 / N/A Mean dental visits: 7.46 / 5.28 Mean pharmacy dispensings: 61.69 / 35.91 Mean outpatient visits: 4. /
#
# --- Document 31 ---
# Source: tmjDoc2 | Page: 7 | Type: UncategorizedText
# Content length: 87 characters
# Content:
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Document 32 ---
# Source: tmjDoc2 | Page: 8 | Type: Table
# Content length: 141 characters
# Content:
# Pub. Study Study . . Measure Results Year Population Design Source Mean outside claim/referral Inpatient: 0.09 / 0.08 Outpatient: 2.66 / 2.14
#
# --- Document 33 ---
# Source: tmjDoc2 | Page: 8 | Type: ListItem
# Content length: 84 characters
# Content:
# Health Info: Temporomandibular Disorders <https://www.nidcr.nih.gov/health-info/tmd>
#
# --- Document 34 ---
# Source: tmjDoc2 | Page: 8 | Type: ListItem
# Content length: 165 characters
# Content:
# e Learn more about TMD research supported by NIDCR: Research Investments and Advances <https://www.nidcr.nih.gov/grants-funding/funded-research/research-investments-
#
# --- Document 35 ---
# Source: tmjDoc2 | Page: 8 | Type: ListItem
# Content length: 251 characters
# Content:
# 1. Lipton JA, Ship JA, Larach-Robinson D. Estimated prevalence and distribution of reported orofacial pain in the United States <https://pubmed.ncbi.nlm.nih.gov/8409001/>. J Am Dent Assoc. 1993 Oct;124(10):115-21. doi: 10.14219/jada.archive.1993.0200.
#
# --- Document 36 ---
# Source: tmjDoc2 | Page: 8 | Type: ListItem
# Content length: 200 characters
# Content:
# 2. Plesh O, Adams SH, Gansky SA. Racial/ethnic and gender prevalences in reported common pains in a national sample <https://pubmed.ncbi.nlm.nih.gov/21359234/>. J Orofac Pain. 2011 Winter;25(1):25-31.
#
# --- Document 37 ---
# Source: tmjDoc2 | Page: 8 | Type: ListItem
# Content length: 223 characters
# Content:
# 3. Alkhubaizi Q, Sorkin JD, Hochberg MC, Gordon SM. Risk factors for facial pain: Data from the Osteoarthritis Initiative Study <https://pubmed.ncbi.nlm.nih.gov/30211397/>. J Dent Oral Biol. 2017;2(3):1033. Epub 2017 Feb 9.
#
# --- Document 38 ---
# Source: tmjDoc2 | Page: 8 | Type: ListItem
# Content length: 558 characters
# Content:
# 4. National Academies of Sciences, Engineering, and Medicine; Health and Medicine Division; Board on Health Care Services; Board on Health Sciences Policy; Committee on Temporomandibular Disorders (TMDs): From Research Discoveries to Clinical Treatment. Appendix C, Prevalence, impact, and costs of treatment for temporomandibular disorders <https://www.ncbi.nlm.nih.gov/books/nbk557996/>. In: Yost O, Liverman CT, English R, editors. Temporomandibular disorders: Priorities for research and care. Washington (DC): National Academies Press (US); 2020 Mar 12.
#
# --- Document 39 ---
# Source: tmjDoc2 | Page: 8 | Type: ListItem
# Content length: 167 characters
# Content:
# 5. National Academies of Sciences, Engineering, and Medicine; Health and Medicine Division; Board on Heaun Care Services; Board on Health Sciences Policy; Committee on
#
# --- Document 40 ---
# Source: tmjDoc2 | Page: 8 | Type: UncategorizedText
# Content length: 86 characters
# Content:
# Research Discoveries to Clinical Treatment. Chapter 3, Individ' Was this page helpful?
#
# --- Document 41 ---
# Source: tmjDoc2 | Page: 8 | Type: UncategorizedText
# Content length: 67 characters
# Content:
# <https://www.ncbi.nlm.nih.gov/books/nbk558001/>. In: Yost O, Liverm
#
# --- Document 42 ---
# Source: tmjDoc2 | Page: 8 | Type: UncategorizedText
# Content length: 64 characters
# Content:
# disorders: Priorities for research and care. Washington (DC): Na
#
# --- Document 43 ---
# Source: tmjDoc2 | Page: 8 | Type: ListItem
# Content length: 132 characters
# Content:
# 6. Shimshak DG, DeFuria, MC. Health care utilization by patients <https://pubmed.ncbi.nlm.nih.gov/9852811/>. Cranio.1998 Jul;16(3):)
#
# --- Document 44 ---
# Source: tmjDoc2 | Page: 8 | Type: ListItem
# Content length: 148 characters
# Content:
# 7. White BA, Williams LA, Leben JR. Health care utilization cost a! members with temporomandibular disorders <https://pubmed.n Spring;15(2):158-169.
#
# --- Document 45 ---
# Source: tmjDoc2 | Page: 8 | Type: UncategorizedText
# Content length: 87 characters
# Content:
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain
#
# --- Document 46 ---
# Source: tmjDoc2 | Page: 9 | Type: Table
# Content length: 467 characters
# Content:
# Home<j Web Policies </about-us/web-policies> Privacy </about-us/privacy-policy> Contact Us </about-us/contact-nider> Freedom of Information Act No Fear Act </about-us/freedom-information-act- <https://www.edi.nih.gov/no-fear-act> requests> Office of Inspector General HHS Vulnerability Disclosure Employee Intranet - Staff Only <https://oig.hhs.gov/> <https://www.hhs.gov/vulnerability- <https://nih.sharepoint.com/sites/nidcr- disclosure-policy/index.html> intranet>
#
# --- Document 47 ---
# Source: tmjDoc2 | Page: 9 | Type: UncategorizedText
# Content length: 87 characters
# Content:
# https://www.nidcr.nih.gov/research/data-statistics/temporomandibular-disorders-jaw-pain

# %%
#Print the chunked documents
for i, doc in enumerate(chunked_docs, 1):
    meta = doc.metadata
    print(f"--- Chunk {i} ---")
    print(f"source={meta.get('source')} page={meta.get('page_number')} type={meta.get('type')} section={meta.get('section')}")
    print(doc.page_content)
    print()

# %%
#Create embeddings
embeddings = OpenAIEmbeddings(
    model="text-embedding-3-small",
)

# %%
#Create Chroma db
vector_store = Chroma(
    collection_name="tmj_rag_app",
    embedding_function=embeddings,
    persist_directory="../data/chroma_db"
)

# %%
#Add documents to the vector store and persist vector store
vector_store.add_documents(chunked_docs)
# Out:
# ['68159ad0-2139-411c-af69-b6d2ac22d967',
#  'a32713d8-2cf7-4ddd-835c-1e4a308445fe',
#  'ae6f5dd4-a6bd-4473-907b-90d5baf0d462',
#  '0b5ee6b2-e0f8-4600-9273-d3ec26a2aa74',
#  'd48f0708-3918-489b-a913-b13fdce3c43d',
#  '0a392bc3-cbb7-4b50-b8a6-61ace5ddb6e2',
#  '5cd46457-a4ef-4324-bd6a-f920963560c2',
#  'f147b413-c993-4e48-82e4-2f2cc85464b3',
#  '1b71ba49-e9e9-40b3-b42f-b5760b96b9ca',
#  'de09603e-c3e5-4cf2-b360-003fe06601e4',
#  '6ab9438f-4bb3-46dd-8d3b-ebe0054e1cdc',
#  '16e67336-897c-4f81-bd96-7811e4e777ec',
#  'e0b11cf3-5b39-4ba3-8257-a25085ab277a',
#  'defef2c3-d09b-4e5e-8980-9ee674a34622',
#  '7bb15130-22e4-45bc-8aee-4b9262eaa3d5',
#  'a4d456bd-2f14-42d5-9f61-2c1ac83a188b',
#  'b6ac6736-fb3d-45b8-ad00-c8de407f0e36',
#  '91123220-85bd-4f02-94b1-bbc81e16ce75',
#  '4f82406a-15a4-4e62-ba92-98731303d10e',
#  '954fdb08-4e3f-4722-a5c4-feb6a56ed985',
#  '1f75e589-a8e1-4167-85a3-a3aba8ecfa3e',
#  '5da46d03-720d-4969-8729-4833d15df91c',
#  '8f61bb98-ead5-446f-8aee-f3191fa7c8ca',
#  '11e061da-db86-4c99-b5c9-dc82c70ae01f',
#  '397917cf-71e4-4482-ae70-c38192ec610c',
#  'd162b882-e788-4e48-9775-6e116c56b569',
#  'a2a75396-b827-4007-bd78-a5f7eaafa8aa',
#  'a2c9b21d-8748-47f5-bf90-c1a2ef4e28e5',
#  'b14bde5f-9268-499f-aebc-81848827269d',
#  '45897f50-eaf0-486c-b21c-d976722432db',
#  '6ff92920-3ad8-4c19-b09f-9c09f8303ab4',
#  'd8ad7163-e354-46d8-89c4-90c0e101adcc',
#  'c0ccaf57-9b4e-4249-b740-f8820ca8a516',
#  'cb38c610-d25a-4566-86f4-47201a5d8852',
#  'ae28fb6e-0e86-46ce-96b4-40510297b3ff',
#  'bf4ec293-c82e-47e6-b260-206055e60d47',
#  '8f98811b-ee98-494d-9860-db50877f7046',
#  '493fb621-1cb9-4586-b3ae-1f9221dd69c3',
#  'dbb2e53a-2fd5-40ed-b3a7-9989555c58b8',
#  '414591b3-4fbd-4a8a-bca5-23867f64ce62',
#  '443cda95-099a-4b9e-9ada-4cc3852bdd51',
#  '75141025-be06-4685-9988-373e83d27979',
#  '808c92b1-95ea-4c9e-9c75-532513edf1f6',
#  '98009660-b2c9-4f35-81d0-1810a5210916',
#  '38bbcef4-26d2-43d8-a29c-0e6d477dcbc7',
#  'd5aaedc9-01c0-4a95-b43d-0c4972a683b6',
#  'b2d7a0aa-09fc-4a3b-88f0-ffff6fa3e962',
#  '7ac86428-61ce-4d1c-9990-e69653803b97',
#  'dc6f78bb-f01d-4dda-bd83-a84c9f5306d2',
#  'dfe2b8e7-a861-4b60-884f-c7cf680d16ea',
#  'e839f678-c6b2-4065-b349-59923977490a',
#  'e2900202-eced-45ff-9a43-c3016b7faa29',
#  '34bff7d4-1694-4073-bf6e-3605153bf8d6',
#  '733b9455-cb76-48b4-839d-faec5943585d',
#  'a4a46331-ef2b-4f1c-8c94-eb7262461ea2',
#  'db7d68e7-b662-4ae6-a568-6e8c01a485c8',
#  'b313a10b-f02d-4579-8173-fe01da7753ec',
#  '533a0c77-8bc2-4ce7-9b42-d8862cb5cc73',
#  '701ad4d8-2696-45fa-9cbc-8ee787a9a937',
#  '8d9eee5d-d28e-4664-8a50-3d2dd3737f61',
#  '666bdce0-e225-4ba7-9eea-86083c1afa4a',
#  '494ae0bf-2aff-49d9-8103-52f9b71819e5',
#  '0802edd3-8d47-467e-a122-b219b04654ad',
#  '4d0819bb-305e-4d36-9665-e6baea653c5c',
#  '7fce3099-56ee-4b48-b33c-c0baba185bed',
#  '02fe7c50-f1ff-44ed-970a-e9959b2098fd',
#  '7d04a460-d7f6-4c5b-9073-2f7417cac6cb',
#  '08730581-7049-4e4b-8001-987659487391',
#  'bafcda4c-ad0d-4a7f-b3df-cb468c4f4aa3',
#  'd7aa547b-1d30-4cbf-86da-d9d0e355f8c0',
#  '0a57ddf8-e324-402e-b52c-ff43451ef0af',
#  '3ac85abd-f96a-4ae8-a320-5a12947c94b5',
#  'ad25f6a0-21d6-480b-a5ee-e9d014eb0e32',
#  '7ac408bf-3f87-4685-9a96-187b79fbaf83',
#  '5f94c74c-fe89-42d3-9dcf-867bb2df8141',
#  '247832fc-c572-4f03-8a9a-bb2157bb7cba',
#  '9e7db45c-8c9c-45c4-8503-f4c0b0765325',
#  'd232b661-29ef-429b-b99b-06fc6f4634f3',
#  '3e7c0d38-e81d-40aa-a729-0f811cadaf4f',
#  'a1a2538a-fd40-483b-8a49-d991c9d3d50c',
#  'ef1264cf-58c2-4fd1-b5d9-5e9cc336788d',
#  '6b83d85c-c1ad-43a4-bae9-c1bbd4250fe8',
#  '81418ce9-c8f6-4a56-8c4e-6b1516bd9579',
#  '278acad5-709d-4bed-accf-bc806f0657b6',
#  '0c801ec9-3fec-459b-b28c-81daba25c275',
#  '4acaade0-8f47-4c2e-8f54-86d6a55cf035',
#  'b383451c-920f-4c3a-9142-da249b3c50de',
#  'b00ed801-a324-4b76-b31c-64a49d5130f1',
#  '6958d3b7-b506-4e0b-a5b6-3eaa7837f428',
#  'ddb4ea51-023d-4772-beec-743046d1d461',
#  '05f7747c-aa7b-49d8-bd54-de7dfe7b5172',
#  'f3819237-3abf-4e99-8611-2b27ed2388b0',
#  'cfe914ec-ef48-4ec6-9e37-b2a8cde5bcb5',
#  '8094d66f-94e7-4761-813e-0e8d85b77955',
#  '760cde40-18c7-43bf-94d5-0f37def893b2',
#  'd5d16ebc-a5aa-4d8b-970b-15cf2ce7c282',
#  'e78b6285-48af-4445-a55a-60cf11643c76',
#  '35e51c01-03d2-4717-8037-f47047c1eb0d',
#  'be086c8e-9413-41f2-8640-dfa9f622dd8b',
#  '68202327-3dcb-4828-a7fa-2a2c4a97f56a',
#  'bdad01ef-a8ad-4a66-be2b-afcadebfceb5',
#  '0acbd7d2-2e89-487f-b649-28736fbcd7f5',
#  '7d9a8900-abee-45fd-8849-1fcd3cda9e71',
#  '2032bb54-8834-4901-a141-cbfe7a30f20a',
#  '6e087181-b114-41f3-83a1-f7e8e589bc34',
#  '69db574b-9f7c-4056-87f7-50fac9b15611',
#  'f90a07d7-709f-4ca2-bb27-65e8a7c6cdbe',
#  'b5eccb1f-e851-4451-87b4-f42e22f4bcc2',
#  'dcbfa025-69ce-40a8-8f83-61254b91e4c8',
#  '9c973686-11e0-4ffd-8848-ec764b9a369c',
#  'fe8e82c7-75e8-44de-9880-8c0bc6d342cd',
#  'a6f1f4fa-7759-4742-997e-9616d23606a3',
#  '10b13e99-c6cb-439e-8160-30f3c2d3018c',
#  'aae726ce-e5bb-4d49-9897-baac2322b1c8',
#  '5a3f0675-7a97-4351-b527-b2a462f9b03e',
#  '6dadc2b3-91c5-453f-863e-bb8d6cf52352',
#  '961146c2-7e7b-4052-b682-00539507c437',
#  '1010c40b-49a6-4720-8077-8f53795fb5d8',
#  '7ffc36d7-ba85-486b-938e-4d62a55f1cbe',
#  '33e677bb-e6d1-4c26-bce3-9139844f7eee',
#  'da2803ab-2ba7-4ea6-a8fb-955d92ef6a9c',
#  'b14463a2-dc35-42f1-ade9-36a2456a4de8',
#  'db9732f4-99bd-443c-8991-5be6de401c6d',
#  'b4836a18-55b8-4f8b-82d4-9c10fbb1f228',
#  'f1b905aa-4dbc-4d88-bb55-9e4cfb561520',
#  '24dec76c-d026-45ba-b814-2d40d7d846cf',
#  '883a0fc9-88ac-4bd2-bd8d-f0a6836e09d9',
#  '0098d7f7-b05b-47d7-a546-80a93449c0de',
#  '4ee9a7e8-9017-4db7-b59a-281b9f9ba7ef',
#  '6f677539-34c9-48a0-8513-260d89e3b87e',
#  'c59a1fa9-cf8e-4033-b8ad-f1d3afab05f0',
#  '89a32417-aa2e-474f-b310-96fa35168bde',
#  '03de458d-3c19-4f50-9b3c-9af3aa39a699',
#  'e152faa3-69c1-4c9b-91a0-1ce62cbf12f8',
#  'a1966483-4092-4831-8e27-5096532d5e34',
#  '0d5be556-b4f6-4b1f-96dd-08db5195314a',
#  '826c09ce-bc58-42f8-a208-351a0244fe52',
#  '93228724-20a1-4e0d-879e-6d219939da7a',
#  '2f58cee3-00e4-46b8-a15f-3012556b422a',
#  'ee08caf5-0ca2-4a40-a32a-277558a6817c',
#  '46bab7fb-752f-4036-abf2-441c5793df17',
#  'ecd0f665-7372-44fc-9323-b7a735e931f8',
#  'c6640f2c-e840-46fd-ae15-13d2c48dd2ac',
#  '9b910b37-d167-437b-b334-0bacde988143',
#  '9424ce3a-e6c6-4af6-bd0b-76c4ed4407a4',
#  '538bb536-2a7c-4a6b-b2f9-b59a8730cb98',
#  'b87cf0ba-56af-4a32-9a46-842dd842c313',
#  'db36f78b-7337-4243-b85d-c64583cc9902',
#  '6b5df29b-5166-4919-9901-d6590c447c58',
#  '56cb85c2-0a6f-4c9c-a0a8-be8bba682f98',
#  '62c9e5cf-4f88-4e6d-a36a-60514ca087e1',
#  'f8b5239a-8fc0-4072-b8d3-d73ec9ae7666',
#  'd447c62d-43ad-4b3c-b9b5-739eea112bd8',
#  '2718c83e-8f5d-4258-85bc-be41b6fa84c7',
#  '620b61be-128d-4cee-bc85-c9c2b721e6e9',
#  '1a85c2e4-2988-4ab9-aec9-6e65d4867e0d',
#  'c5851e26-9475-431f-bf6e-3533b1ea7e76',
#  'b977c326-4ba7-4e05-b4f7-92f93c3fe7de',
#  '5d9420d6-17d4-47eb-b75e-fed756841a52',
#  '30e18816-85c1-4be8-9e68-430134979377',
#  '53a759ba-0d46-44b7-b8b0-9034ac84be32',
#  'de4fb96f-98e1-4e65-8d49-10385ca6fae2',
#  '9aba42c7-3a19-4a5e-bd8e-3780c6290380',
#  'fa12d718-efd2-4833-9d06-189130a38ff9',
#  'd67c4ff3-48a4-4f31-974a-85db0fb02922',
#  'a26897c6-d248-49f2-ae31-3a0c853aac93',
#  '0d29b320-4ad4-4233-8a16-7d53783d450e',
#  '904a255f-fcf1-4ff9-901f-221516948bab',
#  '6944f8fb-0506-446b-846c-ed8e619a364a',
#  '812b7033-014f-43ce-8a88-dee7a91a59ca',
#  '5045a366-547e-4326-a1ba-5679bc50c33b',
#  '8133d339-80a1-4c7f-9aeb-a5e3db040c3b',
#  'bce5a2ca-f682-46d4-9d47-20488dfe2b63',
#  '8e8f4382-f415-4848-b46b-49bd6d66c27d',
#  'df938bc4-9bea-4fdd-8c77-efcad028bc39',
#  'ad547c73-5508-473d-bc1c-f53011fd4562',
#  '3cf78292-67d4-4afc-ada9-23825683ed64',
#  '24187e57-d811-493e-a4e8-345fa6bac62c',
#  '92544227-dbf3-4e16-9014-0325a358bba2',
#  'ed630fe0-d9cd-4b3f-a627-65fb03107665',
#  '70f5d761-d3c1-4aed-9fbd-7daf9540801a',
#  'b6d7167c-2c1a-4956-9ddc-739938e0950f',
#  '9c4658c8-47e5-47a4-be9e-e525fe2bb734',
#  '0c1b85cb-41a0-4eae-b9b7-fe4334183894',
#  '4354da6f-e013-4532-bb22-7700cf3f88a3',
#  '262a06f8-5ae2-4e80-8ced-ffe2c07cf30a',
#  'de1dd781-3f46-43f5-bbcd-446338c83d72',
#  '176d63af-5830-48e5-9ed6-742f6cd561ba',
#  '3f06c7bc-9f78-4b3a-a66e-ea99fe76fd34',
#  'a142c34c-cdca-4986-929a-2bf12285adcd',
#  'cfb6ffdd-a93f-45b4-ab4e-8e5ba8c1548d',
#  '5317450b-deed-454f-9c7f-97f7692302af',
#  'aaa2977e-71fb-49fc-9b07-48340eb0b00e',
#  'd6bb1372-92c6-4fcc-b3f1-b0d5807ea052',
#  '25e8d5ec-9550-40f8-a8ef-aacc8406347d',
#  'e753751e-7363-41df-a2a6-9efefd04af03',
#  '40bb3420-3121-42e2-9ef8-872238ccd904',
#  'c3110151-3943-4b4d-8724-98cdf52a953f',
#  '33bb32dd-177a-4598-9150-85a1ba1311a1',
#  'b23c988c-bdb1-4e10-b158-07d66377ed57',
#  'd73b3b12-3c8e-48a0-bf14-fddbd3515749',
#  'e0a7f97c-ff74-481e-98b9-ecc7e501fd0f',
#  '887e6fd4-de75-41f8-b3d7-6c5980cb2546',
#  '2b886085-bfaa-49b4-8be6-819dc095a1f5',
#  'a8db5aa5-575e-4390-a1dc-15987dcc3030',
#  '03c1a27a-7e48-47a7-96af-80eb6e5a4a88',
#  '4dbfbc28-f80f-4bb1-88cf-6534184b2a3f',
#  '09520474-85b1-4c1f-b473-ea1ef07e1765',
#  'c074a6af-8da9-4305-850e-2f67e88f5f93',
#  '7a66e503-7a8a-4adc-b310-06d48e6ede01',
#  '564d8263-6a08-4c93-b561-4e7c663692f0',
#  '6cf2bac0-6068-43c2-8090-65ef04914ede',
#  '3299052f-cb16-416b-b7a1-e30aab9a4ac4',
#  '4fc5e3f9-23ce-4343-aaf2-55a6b1ca9afe',
#  'e2032f7b-fa11-4c0d-898e-fee7ab2202ce',
#  '206b2db8-60ee-48ba-ab5e-f094963ce58f',
#  '9d61344c-c9c8-41c4-9605-8063cbb168ba',
#  '138efdbb-dc32-4bdb-bee0-98fb7b0dd873',
#  '8a812af4-631a-4117-986f-86d65578e6fe',
#  'a1e5a1a7-3195-45eb-aea1-21a7da7efd6a']

# %%
#Prompt template
medical_template = ChatPromptTemplate.from_messages([
    ("system",
     "You are a medical information assistant specializing in TMJ disorders. "
     "Answer ONLY using the provided context. "
     "If the context does not contain enough information, say so clearly. "
     "Use precise medical terminology. "
     "This is for informational purposes only and does not replace professional medical advice."),
    ("human",
     "Context:\n{context}\n\nQuestion:\n{question}\n\nAnswer:")
])

#Build retriever from vector store
retriever = vector_store.as_retriever(
    searchType="mmr",
    searchKwargs={"k": 3}
)


#Function to format docs and create RunnableLambda
def format_docs(docs):
    return "\n\n".join(doc.page_content for doc in docs)

format_docs_runnable = RunnableLambda(format_docs)

output_parser = StrOutputParser()

# %%
#Initialize LLM
llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature = 0.0
)

# %%
#Create RAG chain
rag_chain = (
    {
        "context": retriever | format_docs_runnable,
        "question": RunnablePassthrough(),
    }
    | medical_template
    | llm
    | output_parser  
)

# %%
#Query the chain
answer = rag_chain.invoke("Explain arthroscopy for TMJ")
print(answer)
# Out:
# Arthroscopy for TMJ (temporomandibular joint) is a minimally invasive surgical procedure used to diagnose and treat various disorders of the TMJ. During the procedure, a small camera (arthroscope) is inserted into the joint space through a small incision. This allows the surgeon to visualize the internal structures of the joint, including the articular disc, ligaments, and surrounding tissues.
#
# Arthroscopy can be used to remove adhesions, repair damaged tissues, or address other abnormalities within the joint. It is typically indicated for patients who have not responded to conservative treatments such as physical therapy, medications, or splints. The benefits of arthroscopy include reduced recovery time, less postoperative pain, and minimal scarring compared to open joint surgery.
